# %% [markdown]
# # DataLab 2: Voetbal & Data Science <a name='begin'></a>
#
# <br>Groepsnummer: 3B
# <br>Sprintnummer: 4 <br><br> Leden:
# <br>    **Busse Heemskerk** 22122877
# <br>    **Isa Dijkstra**                             22119485
# <br> **Jacco van den Dobbelsteen**  17100976
# <br>    **Johan Heskes**                        22132376
# <br>    **Tim Oosterling**                        22078800

# %% [markdown]
# ## Table of Contents
#
# 1. [Importeren van de dataset in Python](#dataset)
# 2. [Sprint 2](#spr2)
#     1. [Beschrijven van de tabellen](#tabellen)
#     2. [Bekijken van de data van Heracles Almelo](#hadata)
#     3. [Eigen functies; Statistieken per seizoen bepalen](#define1)
#         1. [Het runnen van de functies](#run1)
# 3. [Sprint 3](#spr3)
#     1. [Eigen functies: Prestaties van Heracles Almelo](#prestatie)
#         1. [Bekijken van de prestaties](#prebekijk)
#     2. [Eigen functies: Onderzoek teameigenschappen](#team)
#         1. [Het aanmaken van de tabel](#kolmaken)
#     3. [Eigen functies: Visualisaties voor team statistiek](#visu1)
#         1. [Tonen van de grafieken](#run3)
# 4. [Sprint 4](#spr4)
#     1. [Eigen functie: Statistieken per speler](#spelerstat)
#     2. [Eigen functies: Speler ratings](#ratingspeler)
#         1. [Onderzoeken van de ratings](#rating)

# %% [markdown]
# ## Importeren van de dataset in Python <a name='dataset'></a>

# %% [markdown]
# Voordat er gecodeerd wordt, worden de mogelijk nodige libraries voor de opdrachten geïmporteerd

# %%
import sqlite3
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from functools import wraps

sns.set_style('darkgrid')

# %% [markdown]
# Eerst word er een connectie gemaakt met de SQL-database door middel van sqlite3, vervolgens worden de tabellen per stuk geïmporteerd door middel van Pandas.

# %%
connect = sqlite3.connect('database.sqlite')

country = pd.read_sql_query("SELECT * FROM Country", connect)
league = pd.read_sql_query("SELECT * FROM League", connect)
match = pd.read_sql_query("SELECT * FROM Match", connect)
player = pd.read_sql_query("SELECT * FROM Player", connect)
player_attributes = pd.read_sql_query("SELECT * FROM Player_attributes", connect)
team = pd.read_sql_query("SELECT * FROM Team", connect)
team_attributes = pd.read_sql_query("SELECT * FROM Team_attributes", connect)

# %% [markdown]
# Vervolgens wordt de optie om de kolommen in te korten uitgezet, daarna worden alle kolommen getoont.

# %%
pd.set_option("display.max_columns", None)
display(country, league, match, player, player_attributes, team, team_attributes)
# Out:
#        id         name
# 0       1      Belgium
# 1    1729      England
# 2    4769       France
# 3    7809      Germany
# 4   10257        Italy
# 5   13274  Netherlands
# 6   15722       Poland
# 7   17642     Portugal
# 8   19694     Scotland
# 9   21518        Spain
# 10  24558  Switzerland
#        id  country_id                      name
# 0       1           1    Belgium Jupiler League
# 1    1729        1729    England Premier League
# 2    4769        4769            France Ligue 1
# 3    7809        7809     Germany 1. Bundesliga
# 4   10257       10257             Italy Serie A
# 5   13274       13274    Netherlands Eredivisie
# 6   15722       15722        Poland Ekstraklasa
# 7   17642       17642  Portugal Liga ZON Sagres
# 8   19694       19694   Scotland Premier League
# 9   21518       21518           Spain LIGA BBVA
# 10  24558       24558  Switzerland Super League
#           id  country_id  league_id     season  stage                 date  \
# 0          1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1          2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2          3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3          4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4          5           1          1  2008/2009      1  2008-08-16 00:00:00
# ...      ...         ...        ...        ...    ...                  ...
# 25974  25975       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25975  25976       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25976  25977       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25977  25978       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25978  25979       24558      24558  2015/2016      9  2015-09-23 00:00:00
#
#        match_api_id  home_team_api_id  away_team_api_id  home_team_goal  \
# 0            492473              9987              9993               1
# 1            492474             10000              9994               0
# 2            492475              9984              8635               0
# 3            492476              9991              9998               5
# 4            492477              7947              9985               1
# ...             ...               ...               ...             ...
# 25974       1992091             10190             10191               1
# 25975       1992092              9824             10199               1
# 25976       1992093              9956             10179               2
# 25977       1992094              7896             10243               0
# 25978       1992095             10192              9931               4
#
#        away_team_goal  home_player_X1  home_player_X2  home_player_X3  \
# 0                   1             NaN             NaN             NaN
# 1                   0             NaN             NaN             NaN
# 2                   3             NaN             NaN             NaN
# 3                   0             NaN             NaN             NaN
# 4                   3             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 25974               0             1.0             2.0             4.0
# 25975               2             1.0             3.0             5.0
# 25976               0             1.0             2.0             4.0
# 25977               0             1.0             2.0             4.0
# 25978               3             1.0             2.0             4.0
#
#        home_player_X4  home_player_X5  home_player_X6  home_player_X7  \
# 0                 NaN             NaN             NaN             NaN
# 1                 NaN             NaN             NaN             NaN
# 2                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 4                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 25974             6.0             8.0             4.0             6.0
# 25975             7.0             2.0             4.0             6.0
# 25976             6.0             8.0             4.0             6.0
# 25977             6.0             8.0             3.0             7.0
# 25978             6.0             8.0             2.0             4.0
#
#        home_player_X8  home_player_X9  home_player_X10  home_player_X11  \
# 0                 NaN             NaN              NaN              NaN
# 1                 NaN             NaN              NaN              NaN
# 2                 NaN             NaN              NaN              NaN
# 3                 NaN             NaN              NaN              NaN
# 4                 NaN             NaN              NaN              NaN
# ...               ...             ...              ...              ...
# 25974             3.0             5.0              7.0              5.0
# 25975             8.0             5.0              4.0              6.0
# 25976             3.0             5.0              7.0              5.0
# 25977             5.0             3.0              5.0              7.0
# 25978             6.0             8.0              4.0              6.0
#
#        away_player_X1  away_player_X2  away_player_X3  away_player_X4  \
# 0                 NaN             NaN             NaN             NaN
# 1                 NaN             NaN             NaN             NaN
# 2                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 4                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 25974             1.0             2.0             4.0             6.0
# 25975             1.0             2.0             4.0             6.0
# 25976             1.0             2.0             4.0             6.0
# 25977             1.0             2.0             4.0             6.0
# 25978             1.0             2.0             4.0             6.0
#
#        away_player_X5  away_player_X6  away_player_X7  away_player_X8  \
# 0                 NaN             NaN             NaN             NaN
# 1                 NaN             NaN             NaN             NaN
# 2                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 4                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 25974             8.0             4.0             6.0             3.0
# 25975             8.0             3.0             5.0             7.0
# 25976             8.0             4.0             6.0             3.0
# 25977             8.0             4.0             6.0             3.0
# 25978             8.0             4.0             6.0             3.0
#
#        away_player_X9  away_player_X10  away_player_X11  home_player_Y1  \
# 0                 NaN              NaN              NaN             NaN
# 1                 NaN              NaN              NaN             NaN
# 2                 NaN              NaN              NaN             NaN
# 3                 NaN              NaN              NaN             NaN
# 4                 NaN              NaN              NaN             NaN
# ...               ...              ...              ...             ...
# 25974             5.0              7.0              5.0             1.0
# 25975             3.0              5.0              7.0             1.0
# 25976             5.0              7.0              5.0             1.0
# 25977             5.0              7.0              5.0             1.0
# 25978             5.0              7.0              5.0             1.0
#
#        home_player_Y2  home_player_Y3  home_player_Y4  home_player_Y5  \
# 0                 NaN             NaN             NaN             NaN
# 1                 NaN             NaN             NaN             NaN
# 2                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 4                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 25974             3.0             3.0             3.0             3.0
# 25975             3.0             3.0             3.0             7.0
# 25976             3.0             3.0             3.0             3.0
# 25977             3.0             3.0             3.0             3.0
# 25978             3.0             3.0             3.0             3.0
#
#        home_player_Y6  home_player_Y7  home_player_Y8  home_player_Y9  \
# 0                 NaN             NaN             NaN             NaN
# 1                 NaN             NaN             NaN             NaN
# 2                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 4                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 25974             6.0             6.0             8.0             8.0
# 25975             7.0             7.0             7.0             9.0
# 25976             6.0             6.0             8.0             8.0
# 25977             7.0             7.0             7.0            10.0
# 25978             7.0             7.0             7.0             7.0
#
#        home_player_Y10  home_player_Y11  away_player_Y1  away_player_Y2  \
# 0                  NaN              NaN             NaN             NaN
# 1                  NaN              NaN             NaN             NaN
# 2                  NaN              NaN             NaN             NaN
# 3                  NaN              NaN             NaN             NaN
# 4                  NaN              NaN             NaN             NaN
# ...                ...              ...             ...             ...
# 25974              8.0             11.0             1.0             3.0
# 25975             11.0             11.0             1.0             3.0
# 25976              8.0             11.0             1.0             3.0
# 25977             10.0             10.0             1.0             3.0
# 25978             10.0             10.0             1.0             3.0
#
#        away_player_Y3  away_player_Y4  away_player_Y5  away_player_Y6  \
# 0                 NaN             NaN             NaN             NaN
# 1                 NaN             NaN             NaN             NaN
# 2                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 4                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 25974             3.0             3.0             3.0             6.0
# 25975             3.0             3.0             3.0             7.0
# 25976             3.0             3.0             3.0             6.0
# 25977             3.0             3.0             3.0             6.0
# 25978             3.0             3.0             3.0             6.0
#
#        away_player_Y7  away_player_Y8  away_player_Y9  away_player_Y10  \
# 0                 NaN             NaN             NaN              NaN
# 1                 NaN             NaN             NaN              NaN
# 2                 NaN             NaN             NaN              NaN
# 3                 NaN             NaN             NaN              NaN
# 4                 NaN             NaN             NaN              NaN
# ...               ...             ...             ...              ...
# 25974             6.0             8.0             8.0              8.0
# 25975             7.0             7.0            10.0             10.0
# 25976             6.0             8.0             8.0              8.0
# 25977             6.0             8.0             8.0              8.0
# 25978             6.0             8.0             8.0              8.0
#
#        away_player_Y11  home_player_1  home_player_2  home_player_3  \
# 0                  NaN            NaN            NaN            NaN
# 1                  NaN            NaN            NaN            NaN
# 2                  NaN            NaN            NaN            NaN
# 3                  NaN            NaN            NaN            NaN
# 4                  NaN            NaN            NaN            NaN
# ...                ...            ...            ...            ...
# 25974             11.0        42231.0       678384.0        95220.0
# 25975             10.0        33272.0        41621.0        25813.0
# 25976             11.0       157856.0       274779.0       177689.0
# 25977             11.0            NaN         8881.0       173534.0
# 25978             11.0       274787.0       492132.0       108451.0
#
#        home_player_4  home_player_5  home_player_6  home_player_7  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 25974       638592.0       413155.0        45780.0       171229.0
# 25975       257845.0       114735.0        42237.0       113227.0
# 25976       294256.0        42258.0        39979.0       173936.0
# 25977        39646.0       282287.0       340790.0       393337.0
# 25978        25815.0        94553.0       384376.0       598355.0
#
#        home_player_8  home_player_9  home_player_10  home_player_11  \
# 0                NaN            NaN             NaN             NaN
# 1                NaN            NaN             NaN             NaN
# 2                NaN            NaN             NaN             NaN
# 3                NaN            NaN             NaN             NaN
# 4                NaN            NaN             NaN             NaN
# ...              ...            ...             ...             ...
# 25974        67333.0       119839.0        143790.0        195215.0
# 25975       358156.0        32343.0        531309.0         37257.0
# 25976       147959.0       451983.0         80564.0        289472.0
# 25977         8893.0       614454.0         93229.0        178142.0
# 25978        36785.0        45174.0        302079.0         71764.0
#
#        away_player_1  away_player_2  away_player_3  away_player_4  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 25974       462944.0       563066.0         8800.0        67304.0
# 25975        42276.0       114792.0       150007.0       178119.0
# 25976        10637.0        67349.0       202663.0        32597.0
# 25977       274776.0       121080.0       197757.0       260964.0
# 25978       156175.0        95216.0       172768.0        22834.0
#
#        away_player_5  away_player_6  away_player_7  away_player_8  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 25974       158253.0       133126.0       186524.0        93223.0
# 25975        27232.0       570830.0       260708.0       201704.0
# 25976       114794.0       188114.0        25840.0       482200.0
# 25977       231614.0       113235.0        41116.0       462608.0
# 25978       458806.0       207234.0        25772.0        40274.0
#
#        away_player_9  away_player_10  away_player_11  goal shoton shotoff  \
# 0                NaN             NaN             NaN  None   None    None
# 1                NaN             NaN             NaN  None   None    None
# 2                NaN             NaN             NaN  None   None    None
# 3                NaN             NaN             NaN  None   None    None
# 4                NaN             NaN             NaN  None   None    None
# ...              ...             ...             ...   ...    ...     ...
# 25974       121115.0        232110.0        289732.0  None   None    None
# 25975        36382.0         34082.0         95257.0  None   None    None
# 25976        95230.0        451335.0        275122.0  None   None    None
# 25977        42262.0         92252.0        194532.0  None   None    None
# 25978        34035.0         41726.0        527103.0  None   None    None
#
#       foulcommit  card cross corner possession  B365H  B365D  B365A   BWH  \
# 0           None  None  None   None       None   1.73   3.40   5.00  1.75
# 1           None  None  None   None       None   1.95   3.20   3.60  1.80
# 2           None  None  None   None       None   2.38   3.30   2.75  2.40
# 3           None  None  None   None       None   1.44   3.75   7.50  1.40
# 4           None  None  None   None       None   5.00   3.50   1.65  5.00
# ...          ...   ...   ...    ...        ...    ...    ...    ...   ...
# 25974       None  None  None   None       None    NaN    NaN    NaN   NaN
# 25975       None  None  None   None       None    NaN    NaN    NaN   NaN
# 25976       None  None  None   None       None    NaN    NaN    NaN   NaN
# 25977       None  None  None   None       None    NaN    NaN    NaN   NaN
# 25978       None  None  None   None       None    NaN    NaN    NaN   NaN
#
#         BWD   BWA   IWH  IWD  IWA   LBH  LBD   LBA  PSH  PSD  PSA   WHH   WHD  \
# 0      3.35  4.20  1.85  3.2  3.5  1.80  3.3  3.75  NaN  NaN  NaN  1.70  3.30
# 1      3.30  3.95  1.90  3.2  3.5  1.90  3.2  3.50  NaN  NaN  NaN  1.83  3.30
# 2      3.30  2.55  2.60  3.1  2.3  2.50  3.2  2.50  NaN  NaN  NaN  2.50  3.25
# 3      4.00  6.80  1.40  3.9  6.0  1.44  3.6  6.50  NaN  NaN  NaN  1.44  3.75
# 4      3.50  1.60  4.00  3.3  1.7  4.00  3.4  1.72  NaN  NaN  NaN  4.20  3.40
# ...     ...   ...   ...  ...  ...   ...  ...   ...  ...  ...  ...   ...   ...
# 25974   NaN   NaN   NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN  NaN   NaN   NaN
# 25975   NaN   NaN   NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN  NaN   NaN   NaN
# 25976   NaN   NaN   NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN  NaN   NaN   NaN
# 25977   NaN   NaN   NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN  NaN   NaN   NaN
# 25978   NaN   NaN   NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN  NaN   NaN   NaN
#
#         WHA   SJH  SJD   SJA   VCH   VCD   VCA   GBH   GBD   GBA   BSH   BSD  \
# 0      4.33  1.90  3.3  4.00  1.65  3.40  4.50  1.78  3.25  4.00  1.73  3.40
# 1      3.60  1.95  3.3  3.80  2.00  3.25  3.25  1.85  3.25  3.75  1.91  3.25
# 2      2.40  2.63  3.3  2.50  2.35  3.25  2.65  2.50  3.20  2.50  2.30  3.20
# 3      6.00  1.44  4.0  7.50  1.45  3.75  6.50  1.50  3.75  5.50  1.44  3.75
# 4      1.70  4.50  3.5  1.73  4.50  3.40  1.65  4.50  3.50  1.65  4.75  3.30
# ...     ...   ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 25974   NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25975   NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25976   NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25977   NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25978   NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#         BSA
# 0      4.20
# 1      3.60
# 2      2.75
# 3      6.50
# 4      1.67
# ...     ...
# 25974   NaN
# 25975   NaN
# 25976   NaN
# 25977   NaN
# 25978   NaN
#
# [25979 rows x 115 columns]
#           id  player_api_id          player_name  player_fifa_api_id  \
# 0          1         505942   Aaron Appindangoye              218353
# 1          2         155782      Aaron Cresswell              189615
# 2          3         162549          Aaron Doran              186170
# 3          4          30572        Aaron Galindo              140161
# 4          5          23780         Aaron Hughes               17725
# ...      ...            ...                  ...                 ...
# 11055  11071          26357       Zoumana Camara                2488
# 11056  11072         111182         Zsolt Laczko              164680
# 11057  11073          36491            Zsolt Low              111191
# 11058  11074          35506  Zurab Khizanishvili               47058
# 11059  11075          39902   Zvjezdan Misimovic              102359
#
#                   birthday  height  weight
# 0      1992-02-29 00:00:00  182.88     187
# 1      1989-12-15 00:00:00  170.18     146
# 2      1991-05-13 00:00:00  170.18     163
# 3      1982-05-08 00:00:00  182.88     198
# 4      1979-11-08 00:00:00  182.88     154
# ...                    ...     ...     ...
# 11055  1979-04-03 00:00:00  182.88     168
# 11056  1986-12-18 00:00:00  182.88     176
# 11057  1979-04-29 00:00:00  180.34     154
# 11058  1981-10-06 00:00:00  185.42     172
# 11059  1982-06-05 00:00:00  180.34     176
#
# [11060 rows x 7 columns]
#             id  player_fifa_api_id  player_api_id                 date  \
# 0            1              218353         505942  2016-02-18 00:00:00
# 1            2              218353         505942  2015-11-19 00:00:00
# 2            3              218353         505942  2015-09-21 00:00:00
# 3            4              218353         505942  2015-03-20 00:00:00
# 4            5              218353         505942  2007-02-22 00:00:00
# ...        ...                 ...            ...                  ...
# 183973  183974              102359          39902  2009-08-30 00:00:00
# 183974  183975              102359          39902  2009-02-22 00:00:00
# 183975  183976              102359          39902  2008-08-30 00:00:00
# 183976  183977              102359          39902  2007-08-30 00:00:00
# 183977  183978              102359          39902  2007-02-22 00:00:00
#
#         overall_rating  potential preferred_foot attacking_work_rate  \
# 0                 67.0       71.0          right              medium
# 1                 67.0       71.0          right              medium
# 2                 62.0       66.0          right              medium
# 3                 61.0       65.0          right              medium
# 4                 61.0       65.0          right              medium
# ...                ...        ...            ...                 ...
# 183973            83.0       85.0          right              medium
# 183974            78.0       80.0          right              medium
# 183975            77.0       80.0          right              medium
# 183976            78.0       81.0          right              medium
# 183977            80.0       81.0          right              medium
#
#        defensive_work_rate  crossing  finishing  heading_accuracy  \
# 0                   medium      49.0       44.0              71.0
# 1                   medium      49.0       44.0              71.0
# 2                   medium      49.0       44.0              71.0
# 3                   medium      48.0       43.0              70.0
# 4                   medium      48.0       43.0              70.0
# ...                    ...       ...        ...               ...
# 183973                 low      84.0       77.0              59.0
# 183974                 low      74.0       76.0              53.0
# 183975                 low      74.0       71.0              53.0
# 183976                 low      74.0       64.0              57.0
# 183977                 low      74.0       68.0              57.0
#
#         short_passing  volleys  dribbling  curve  free_kick_accuracy  \
# 0                61.0     44.0       51.0   45.0                39.0
# 1                61.0     44.0       51.0   45.0                39.0
# 2                61.0     44.0       51.0   45.0                39.0
# 3                60.0     43.0       50.0   44.0                38.0
# 4                60.0     43.0       50.0   44.0                38.0
# ...               ...      ...        ...    ...                 ...
# 183973           89.0     77.0       84.0   86.0                78.0
# 183974           84.0     77.0       85.0   86.0                74.0
# 183975           84.0     77.0       85.0   86.0                74.0
# 183976           86.0     77.0       87.0   86.0                73.0
# 183977           88.0     77.0       87.0   86.0                53.0
#
#         long_passing  ball_control  acceleration  sprint_speed  agility  \
# 0               64.0          49.0          60.0          64.0     59.0
# 1               64.0          49.0          60.0          64.0     59.0
# 2               64.0          49.0          60.0          64.0     59.0
# 3               63.0          48.0          60.0          64.0     59.0
# 4               63.0          48.0          60.0          64.0     59.0
# ...              ...           ...           ...           ...      ...
# 183973          84.0          85.0          66.0          72.0     77.0
# 183974          73.0          86.0          66.0          67.0     77.0
# 183975          73.0          86.0          66.0          67.0     77.0
# 183976          73.0          91.0          61.0          60.0     77.0
# 183977          78.0          91.0          58.0          64.0     77.0
#
#         reactions  balance  shot_power  jumping  stamina  strength  \
# 0            47.0     65.0        55.0     58.0     54.0      76.0
# 1            47.0     65.0        55.0     58.0     54.0      76.0
# 2            47.0     65.0        55.0     58.0     54.0      76.0
# 3            46.0     65.0        54.0     58.0     54.0      76.0
# 4            46.0     65.0        54.0     58.0     54.0      76.0
# ...           ...      ...         ...      ...      ...       ...
# 183973       86.0     73.0        76.0     58.0     72.0      67.0
# 183974       74.0     73.0        75.0     58.0     66.0      65.0
# 183975       74.0     73.0        75.0     58.0     66.0      65.0
# 183976       69.0     73.0        72.0     58.0     67.0      59.0
# 183977       66.0     73.0        72.0     58.0     67.0      59.0
#
#         long_shots  aggression  interceptions  positioning  vision  penalties  \
# 0             35.0        71.0           70.0         45.0    54.0       48.0
# 1             35.0        71.0           70.0         45.0    54.0       48.0
# 2             35.0        63.0           41.0         45.0    54.0       48.0
# 3             34.0        62.0           40.0         44.0    53.0       47.0
# 4             34.0        62.0           40.0         44.0    53.0       47.0
# ...            ...         ...            ...          ...     ...        ...
# 183973        81.0        56.0           78.0         86.0    88.0       83.0
# 183974        73.0        61.0           64.0         72.0    88.0       70.0
# 183975        73.0        67.0           64.0         72.0    88.0       70.0
# 183976        78.0        63.0           63.0         68.0    88.0       53.0
# 183977        78.0        63.0           63.0         68.0    88.0       53.0
#
#         marking  standing_tackle  sliding_tackle  gk_diving  gk_handling  \
# 0          65.0             69.0            69.0        6.0         11.0
# 1          65.0             69.0            69.0        6.0         11.0
# 2          65.0             66.0            69.0        6.0         11.0
# 3          62.0             63.0            66.0        5.0         10.0
# 4          62.0             63.0            66.0        5.0         10.0
# ...         ...              ...             ...        ...          ...
# 183973     22.0             31.0            30.0        9.0         20.0
# 183974     32.0             31.0            30.0        9.0         20.0
# 183975     32.0             31.0            30.0        9.0         20.0
# 183976     28.0             32.0            30.0        9.0         20.0
# 183977     38.0             32.0            30.0        9.0          9.0
#
#         gk_kicking  gk_positioning  gk_reflexes
# 0             10.0             8.0          8.0
# 1             10.0             8.0          8.0
# 2             10.0             8.0          8.0
# 3              9.0             7.0          7.0
# 4              9.0             7.0          7.0
# ...            ...             ...          ...
# 183973        84.0            20.0         20.0
# 183974        73.0            20.0         20.0
# 183975        73.0            20.0         20.0
# 183976        73.0            20.0         20.0
# 183977        78.0             7.0         15.0
#
# [183978 rows x 42 columns]
#         id  team_api_id  team_fifa_api_id      team_long_name team_short_name
# 0        1         9987             673.0            KRC Genk             GEN
# 1        2         9993             675.0        Beerschot AC             BAC
# 2        3        10000           15005.0    SV Zulte-Waregem             ZUL
# 3        4         9994            2007.0    Sporting Lokeren             LOK
# 4        5         9984            1750.0   KSV Cercle Brugge             CEB
# ..     ...          ...               ...                 ...             ...
# 294  49479        10190             898.0       FC St. Gallen             GAL
# 295  49837        10191            1715.0             FC Thun             THU
# 296  50201         9777             324.0         Servette FC             SER
# 297  50204         7730            1862.0  FC Lausanne-Sports             LAU
# 298  51606         7896               NaN              Lugano             LUG
#
# [299 rows x 5 columns]
#         id  team_fifa_api_id  team_api_id                 date  \
# 0        1               434         9930  2010-02-22 00:00:00
# 1        2               434         9930  2014-09-19 00:00:00
# 2        3               434         9930  2015-09-10 00:00:00
# 3        4                77         8485  2010-02-22 00:00:00
# 4        5                77         8485  2011-02-22 00:00:00
# ...    ...               ...          ...                  ...
# 1453  1454             15005        10000  2011-02-22 00:00:00
# 1454  1455             15005        10000  2012-02-22 00:00:00
# 1455  1456             15005        10000  2013-09-20 00:00:00
# 1456  1457             15005        10000  2014-09-19 00:00:00
# 1457  1458             15005        10000  2015-09-10 00:00:00
#
#       buildUpPlaySpeed buildUpPlaySpeedClass  buildUpPlayDribbling  \
# 0                   60              Balanced                   NaN
# 1                   52              Balanced                  48.0
# 2                   47              Balanced                  41.0
# 3                   70                  Fast                   NaN
# 4                   47              Balanced                   NaN
# ...                ...                   ...                   ...
# 1453                52              Balanced                   NaN
# 1454                54              Balanced                   NaN
# 1455                54              Balanced                   NaN
# 1456                54              Balanced                  42.0
# 1457                54              Balanced                  42.0
#
#      buildUpPlayDribblingClass  buildUpPlayPassing buildUpPlayPassingClass  \
# 0                       Little                  50                   Mixed
# 1                       Normal                  56                   Mixed
# 2                       Normal                  54                   Mixed
# 3                       Little                  70                    Long
# 4                       Little                  52                   Mixed
# ...                        ...                 ...                     ...
# 1453                    Little                  52                   Mixed
# 1454                    Little                  51                   Mixed
# 1455                    Little                  51                   Mixed
# 1456                    Normal                  51                   Mixed
# 1457                    Normal                  51                   Mixed
#
#      buildUpPlayPositioningClass  chanceCreationPassing  \
# 0                      Organised                     60
# 1                      Organised                     54
# 2                      Organised                     54
# 3                      Organised                     70
# 4                      Organised                     53
# ...                          ...                    ...
# 1453                   Organised                     52
# 1454                   Organised                     47
# 1455                   Organised                     47
# 1456                   Organised                     47
# 1457                   Organised                     47
#
#      chanceCreationPassingClass  chanceCreationCrossing  \
# 0                        Normal                      65
# 1                        Normal                      63
# 2                        Normal                      63
# 3                         Risky                      70
# 4                        Normal                      48
# ...                         ...                     ...
# 1453                     Normal                      48
# 1454                     Normal                      52
# 1455                     Normal                      52
# 1456                     Normal                      52
# 1457                     Normal                      52
#
#      chanceCreationCrossingClass  chanceCreationShooting  \
# 0                         Normal                      55
# 1                         Normal                      64
# 2                         Normal                      64
# 3                           Lots                      70
# 4                         Normal                      52
# ...                          ...                     ...
# 1453                      Normal                      53
# 1454                      Normal                      50
# 1455                      Normal                      32
# 1456                      Normal                      32
# 1457                      Normal                      32
#
#      chanceCreationShootingClass chanceCreationPositioningClass  \
# 0                         Normal                      Organised
# 1                         Normal                      Organised
# 2                         Normal                      Organised
# 3                           Lots                      Organised
# 4                         Normal                      Organised
# ...                          ...                            ...
# 1453                      Normal                      Organised
# 1454                      Normal                      Organised
# 1455                      Little                      Organised
# 1456                      Little                      Organised
# 1457                      Little                      Organised
#
#       defencePressure defencePressureClass  defenceAggression  \
# 0                  50               Medium                 55
# 1                  47               Medium                 44
# 2                  47               Medium                 44
# 3                  60               Medium                 70
# 4                  47               Medium                 47
# ...               ...                  ...                ...
# 1453               46               Medium                 48
# 1454               44               Medium                 55
# 1455               44               Medium                 58
# 1456               44               Medium                 58
# 1457               44               Medium                 58
#
#      defenceAggressionClass  defenceTeamWidth defenceTeamWidthClass  \
# 0                     Press                45                Normal
# 1                     Press                54                Normal
# 2                     Press                54                Normal
# 3                    Double                70                  Wide
# 4                     Press                52                Normal
# ...                     ...               ...                   ...
# 1453                  Press                53                Normal
# 1454                  Press                53                Normal
# 1455                  Press                37                Normal
# 1456                  Press                37                Normal
# 1457                  Press                37                Normal
#
#      defenceDefenderLineClass
# 0                       Cover
# 1                       Cover
# 2                       Cover
# 3                       Cover
# 4                       Cover
# ...                       ...
# 1453                    Cover
# 1454                    Cover
# 1455                    Cover
# 1456                    Cover
# 1457                    Cover
#
# [1458 rows x 25 columns]

# %% [markdown]
# [Terug naar het begin](#begin)

# %% [markdown]
# # Sprint 2 <a name='spr2' ></a>

# %% [markdown]
# ## Beschrijven van de tabellen <a name='tabellen'></a>

# %% [markdown]
# Hier is de beschrijving van elke tabel gegeven, waarbij de naam en de beschrijving te zien zijn. De beschrijving bevat wat er in de tabel te vinden is.

# %% [markdown]
# | Tabel naam | Tabel beschrijving
# |:-------------------|:---------------
# Country | In deze tabel staan de namen van de landen en de daarbij horende ID's
# League | In deze tabel staan de namen van de competities per land samen met landelijke ID
# Match | In deze tabel staat alle informatie die met wedstrijden te maken heeft en informatie over het wedden op de wedstrijden
# Player | In deze tabel staat info over alle spelers, hun fifa ID, wanneer ze jarig zijn, hun lengte (in cm) en hun gewicht (in lbs)
# Player_attributes | In deze tabel staan de statistieken en rating van elke speler in de database
# Team | In deze tabel staat de id's van de club, de volledige club naam en de afkorting van de club
# Team_attributes | In deze tabel zijn de statistieken van de teams in de database vermeld. zowel offensieve als defensieve statestieken zijn hierbij inbegrepen

# %% [markdown]
# [Terug naar het begin](#begin)

# %% [markdown]
# ## Bekijken van de data van Heracles Almelo <a name='hadata'></a>

# %% [markdown]
# Eerst word er een cell gerunt om de team ID te vinden van onze club: Heracles Almelo

# %%
team[team["team_long_name"] == "Heracles Almelo"]
# Out:
#         id  team_api_id  team_fifa_api_id   team_long_name team_short_name
# 166  26557         9791          100634.0  Heracles Almelo             HER

# %% [markdown]
# De gegevens van het gekozen team staan getoond in de uitkomst van de onderstaande cell.

# %%
team_id = team[team['team_long_name'] == 'Heracles Almelo'].iloc[0,1]
print('Team ID:', team_id)
print('Name:', team[team['team_long_name'] == 'Heracles Almelo'].iloc[0,3])
print('Short name:', team[team['team_long_name'] == 'Heracles Almelo'].iloc[0,4])
print('Country:', 'Netherlands')
print('League id:', country[country['name'] == 'Netherlands'].iloc[0,0])
print("League name:", league[league["id"] == 13274].iloc[0,2])
# Out:
# Team ID: 9791
# Name: Heracles Almelo
# Short name: HER
# Country: Netherlands
# League id: 13274
# League name: Netherlands Eredivisie

# %% [markdown]
# De gegevens van elke wedstrijd die het gekozen team heeft gespeeld per seizoen is hieronder getoond.

# %%
display(match[(match['home_team_api_id'] == team_id) | (match['away_team_api_id'] == team_id)])
# Out:
#           id  country_id  league_id     season  stage                 date  \
# 13278  13279       13274      13274  2008/2009      1  2008-08-31 00:00:00
# 13285  13286       13274      13274  2008/2009     10  2008-11-08 00:00:00
# 13291  13292       13274      13274  2008/2009     11  2008-11-14 00:00:00
# 13303  13304       13274      13274  2008/2009     12  2008-11-22 00:00:00
# 13312  13313       13274      13274  2008/2009     13  2008-11-29 00:00:00
# ...      ...         ...        ...        ...    ...                  ...
# 15683  15684       13274      13274  2015/2016      5  2015-09-13 00:00:00
# 15688  15689       13274      13274  2015/2016      6  2015-09-19 00:00:00
# 15697  15698       13274      13274  2015/2016      7  2015-09-26 00:00:00
# 15703  15704       13274      13274  2015/2016      8  2015-10-02 00:00:00
# 15714  15715       13274      13274  2015/2016      9  2015-10-17 00:00:00
#
#        match_api_id  home_team_api_id  away_team_api_id  home_team_goal  \
# 13278        508307              9791             10235               3
# 13285        523734              9791              8277               0
# 13291        523740              9761              9791               3
# 13303        523752              8640              9791               4
# 13312        523761              9791              8525               1
# ...             ...               ...               ...             ...
# 15683       1983315             10217              9791               0
# 15688       1983320              9791              8640               2
# 15697       1983329             10229              9791               3
# 15703       1983335              9791             10228               2
# 15714       1983346              9791              8593               0
#
#        away_team_goal  home_player_X1  home_player_X2  home_player_X3  \
# 13278               1             0.0             0.0             NaN
# 13285               0             NaN             NaN             NaN
# 13291               0             NaN             NaN             NaN
# 13303               0             NaN             NaN             NaN
# 13312               0             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 15683               1             1.0             2.0             4.0
# 15688               1             1.0             2.0             4.0
# 15697               1             1.0             2.0             4.0
# 15703               0             1.0             2.0             4.0
# 15714               2             1.0             2.0             4.0
#
#        home_player_X4  home_player_X5  home_player_X6  home_player_X7  \
# 13278             NaN             NaN             NaN             NaN
# 13285             NaN             NaN             NaN             NaN
# 13291             NaN             NaN             NaN             NaN
# 13303             NaN             NaN             NaN             NaN
# 13312             NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 15683             6.0             8.0             3.0             5.0
# 15688             6.0             8.0             3.0             5.0
# 15697             6.0             8.0             7.0             3.0
# 15703             6.0             8.0             3.0             5.0
# 15714             6.0             8.0             3.0             5.0
#
#        home_player_X8  home_player_X9  home_player_X10  home_player_X11  \
# 13278             NaN             NaN              NaN              NaN
# 13285             NaN             NaN              NaN              NaN
# 13291             NaN             NaN              NaN              NaN
# 13303             NaN             NaN              NaN              NaN
# 13312             NaN             NaN              NaN              NaN
# ...               ...             ...              ...              ...
# 15683             7.0             3.0              5.0              7.0
# 15688             7.0             3.0              5.0              7.0
# 15697             5.0             3.0              5.0              7.0
# 15703             7.0             3.0              5.0              7.0
# 15714             7.0             3.0              5.0              7.0
#
#        away_player_X1  away_player_X2  away_player_X3  away_player_X4  \
# 13278             NaN             NaN             NaN             NaN
# 13285             NaN             NaN             NaN             NaN
# 13291             NaN             NaN             NaN             NaN
# 13303             NaN             NaN             NaN             NaN
# 13312             NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 15683             1.0             2.0             4.0             6.0
# 15688             1.0             2.0             4.0             6.0
# 15697             1.0             2.0             4.0             6.0
# 15703             1.0             2.0             4.0             6.0
# 15714             1.0             2.0             4.0             6.0
#
#        away_player_X5  away_player_X6  away_player_X7  away_player_X8  \
# 13278             NaN             NaN             NaN             NaN
# 13285             NaN             NaN             NaN             NaN
# 13291             NaN             NaN             NaN             NaN
# 13303             NaN             NaN             NaN             NaN
# 13312             NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 15683             8.0             3.0             5.0             7.0
# 15688             8.0             3.0             5.0             7.0
# 15697             8.0             3.0             5.0             7.0
# 15703             8.0             3.0             5.0             7.0
# 15714             8.0             3.0             5.0             7.0
#
#        away_player_X9  away_player_X10  away_player_X11  home_player_Y1  \
# 13278             NaN              NaN              NaN             0.0
# 13285             NaN              NaN              NaN             NaN
# 13291             NaN              NaN              NaN             NaN
# 13303             NaN              NaN              NaN             NaN
# 13312             NaN              NaN              NaN             NaN
# ...               ...              ...              ...             ...
# 15683             3.0              5.0              7.0             1.0
# 15688             3.0              5.0              7.0             1.0
# 15697             3.0              7.0              5.0             1.0
# 15703             3.0              5.0              7.0             1.0
# 15714             3.0              5.0              7.0             1.0
#
#        home_player_Y2  home_player_Y3  home_player_Y4  home_player_Y5  \
# 13278             0.0             NaN             NaN             NaN
# 13285             NaN             NaN             NaN             NaN
# 13291             NaN             NaN             NaN             NaN
# 13303             NaN             NaN             NaN             NaN
# 13312             NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 15683             3.0             3.0             3.0             3.0
# 15688             3.0             3.0             3.0             3.0
# 15697             3.0             3.0             3.0             3.0
# 15703             3.0             3.0             3.0             3.0
# 15714             3.0             3.0             3.0             3.0
#
#        home_player_Y6  home_player_Y7  home_player_Y8  home_player_Y9  \
# 13278             NaN             NaN             NaN             NaN
# 13285             NaN             NaN             NaN             NaN
# 13291             NaN             NaN             NaN             NaN
# 13303             NaN             NaN             NaN             NaN
# 13312             NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 15683             7.0             7.0             7.0            10.0
# 15688             7.0             7.0             7.0            10.0
# 15697             7.0             7.0             7.0            10.0
# 15703             7.0             7.0             7.0            10.0
# 15714             7.0             7.0             7.0            10.0
#
#        home_player_Y10  home_player_Y11  away_player_Y1  away_player_Y2  \
# 13278              NaN              NaN             NaN             NaN
# 13285              NaN              NaN             NaN             NaN
# 13291              NaN              NaN             NaN             NaN
# 13303              NaN              NaN             NaN             NaN
# 13312              NaN              NaN             NaN             NaN
# ...                ...              ...             ...             ...
# 15683             10.0             10.0             1.0             3.0
# 15688             10.0             10.0             1.0             3.0
# 15697             10.0             10.0             1.0             3.0
# 15703             10.0             10.0             1.0             3.0
# 15714             10.0             10.0             1.0             3.0
#
#        away_player_Y3  away_player_Y4  away_player_Y5  away_player_Y6  \
# 13278             NaN             NaN             NaN             NaN
# 13285             NaN             NaN             NaN             NaN
# 13291             NaN             NaN             NaN             NaN
# 13303             NaN             NaN             NaN             NaN
# 13312             NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 15683             3.0             3.0             3.0             7.0
# 15688             3.0             3.0             3.0             7.0
# 15697             3.0             3.0             3.0             7.0
# 15703             3.0             3.0             3.0             7.0
# 15714             3.0             3.0             3.0             7.0
#
#        away_player_Y7  away_player_Y8  away_player_Y9  away_player_Y10  \
# 13278             NaN             NaN             NaN              NaN
# 13285             NaN             NaN             NaN              NaN
# 13291             NaN             NaN             NaN              NaN
# 13303             NaN             NaN             NaN              NaN
# 13312             NaN             NaN             NaN              NaN
# ...               ...             ...             ...              ...
# 15683             7.0             7.0            10.0             10.0
# 15688             7.0             7.0            10.0             10.0
# 15697             7.0             7.0            10.0             10.0
# 15703             7.0             7.0            10.0             10.0
# 15714             7.0             7.0            10.0             10.0
#
#        away_player_Y11  home_player_1  home_player_2  home_player_3  \
# 13278              NaN        26663.0       110116.0        26671.0
# 13285              NaN            NaN            NaN            NaN
# 13291              NaN            NaN            NaN            NaN
# 13303              NaN            NaN            NaN            NaN
# 13312              NaN            NaN            NaN            NaN
# ...                ...            ...            ...            ...
# 15683             10.0        47532.0       561844.0       109647.0
# 15688             10.0        26589.0       147601.0       213167.0
# 15697             10.0        37206.0       186880.0       245315.0
# 15703             10.0        26589.0       147601.0       213167.0
# 15714             10.0        26589.0       147601.0       213167.0
#
#        home_player_4  home_player_5  home_player_6  home_player_7  \
# 13278        37965.0        26661.0        26664.0        26648.0
# 13285            NaN            NaN            NaN            NaN
# 13291            NaN            NaN            NaN            NaN
# 13303            NaN            NaN            NaN            NaN
# 13312            NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 15683        31731.0       101042.0       110184.0        17855.0
# 15688        31296.0        26455.0       243439.0       248151.0
# 15697        21765.0       174690.0       209413.0       422121.0
# 15703        31296.0       518346.0       243439.0       248151.0
# 15714        31296.0        26455.0       243439.0       248151.0
#
#        home_player_8  home_player_9  home_player_10  home_player_11  \
# 13278        26660.0        26492.0        104045.0             NaN
# 13285            NaN            NaN             NaN             NaN
# 13291            NaN            NaN             NaN             NaN
# 13303            NaN            NaN             NaN             NaN
# 13312            NaN            NaN             NaN             NaN
# ...              ...            ...             ...             ...
# 15683       417818.0        45860.0         20645.0        357230.0
# 15688       213682.0       360560.0        351999.0        281110.0
# 15697       157101.0       261597.0        467022.0        512747.0
# 15703       213682.0       243473.0        351999.0        422128.0
# 15714       213682.0       422128.0        351999.0        518346.0
#
#        away_player_1  away_player_2  away_player_3  away_player_4  \
# 13278        34489.0        26445.0        34492.0        41462.0
# 13285            NaN            NaN            NaN            NaN
# 13291            NaN            NaN            NaN            NaN
# 13303            NaN            NaN            NaN            NaN
# 13312            NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 15683        26589.0       147601.0       213167.0        31296.0
# 15688       150236.0       207642.0       184821.0        70812.0
# 15697        26589.0       147601.0       213167.0        31296.0
# 15703       112107.0       243465.0       611831.0       363369.0
# 15714         5710.0       469804.0       304455.0       496563.0
#
#        away_player_5  away_player_6  away_player_7  away_player_8  \
# 13278        30916.0        24123.0       109638.0       108038.0
# 13285            NaN            NaN            NaN            NaN
# 13291            NaN            NaN            NaN            NaN
# 13303            NaN            NaN            NaN            NaN
# 13312            NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 15683        26455.0       243439.0       248151.0       213682.0
# 15688       389845.0       178765.0       467495.0       209372.0
# 15697        26455.0       243439.0       248151.0       213682.0
# 15703       215369.0       214397.0       110214.0       255221.0
# 15714       352366.0       467479.0       298448.0       178753.0
#
#        away_player_9  away_player_10  away_player_11  \
# 13278        30654.0         37173.0             NaN
# 13285            NaN             NaN             NaN
# 13291            NaN             NaN             NaN
# 13303            NaN             NaN             NaN
# 13312            NaN             NaN             NaN
# ...              ...             ...             ...
# 15683       360560.0        351999.0        281110.0
# 15688       158581.0        150201.0        166575.0
# 15697       253121.0        281110.0        351999.0
# 15703       303926.0             NaN        318809.0
# 15714        39213.0        562267.0        266526.0
#
#                                                     goal  \
# 13278                                               None
# 13285                                               None
# 13291                                               None
# 13303                                               None
# 13312                                               None
# ...                                                  ...
# 15683  <goal><value><comment>n</comment><stats><goals...
# 15688  <goal><value><comment>n</comment><stats><goals...
# 15697  <goal><value><comment>n</comment><stats><goals...
# 15703  <goal><value><comment>n</comment><stats><goals...
# 15714  <goal><value><comment>n</comment><stats><goals...
#
#                                                   shoton  \
# 13278                                               None
# 13285                                               None
# 13291                                               None
# 13303                                               None
# 13312                                               None
# ...                                                  ...
# 15683  <shoton><value><stats><blocked>1</blocked></st...
# 15688  <shoton><value><stats><shoton>1</shoton></stat...
# 15697  <shoton><value><stats><shoton>1</shoton></stat...
# 15703  <shoton><value><stats><blocked>1</blocked></st...
# 15714  <shoton><value><stats><shoton>1</shoton></stat...
#
#                                                  shotoff  \
# 13278                                               None
# 13285                                               None
# 13291                                               None
# 13303                                               None
# 13312                                               None
# ...                                                  ...
# 15683  <shotoff><value><stats><shotoff>1</shotoff></s...
# 15688  <shotoff><value><stats><shotoff>1</shotoff></s...
# 15697  <shotoff><value><stats><shotoff>1</shotoff></s...
# 15703  <shotoff><value><event_incident_typefk>743</ev...
# 15714  <shotoff><value><stats><shotoff>1</shotoff></s...
#
#                                               foulcommit  \
# 13278                                               None
# 13285                                               None
# 13291                                               None
# 13303                                               None
# 13312                                               None
# ...                                                  ...
# 15683  <foulcommit><value><stats><foulscommitted>1</f...
# 15688  <foulcommit><value><stats><foulscommitted>1</f...
# 15697  <foulcommit><value><stats><foulscommitted>1</f...
# 15703  <foulcommit><value><stats><foulscommitted>1</f...
# 15714  <foulcommit><value><stats><foulscommitted>1</f...
#
#                                                     card  \
# 13278                                               None
# 13285                                               None
# 13291                                               None
# 13303                                               None
# 13312                                               None
# ...                                                  ...
# 15683  <card><value><comment>y</comment><stats><ycard...
# 15688  <card><value><comment>y</comment><stats><ycard...
# 15697  <card><value><comment>y</comment><stats><ycard...
# 15703  <card><value><comment>y</comment><stats><ycard...
# 15714  <card><value><comment>y</comment><stats><ycard...
#
#                                                    cross  \
# 13278                                               None
# 13285                                               None
# 13291                                               None
# 13303                                               None
# 13312                                               None
# ...                                                  ...
# 15683  <cross><value><stats><crosses>1</crosses></sta...
# 15688  <cross><value><stats><crosses>1</crosses></sta...
# 15697  <cross><value><stats><crosses>1</crosses></sta...
# 15703  <cross><value><stats><crosses>1</crosses></sta...
# 15714  <cross><value><stats><crosses>1</crosses></sta...
#
#                                                   corner  \
# 13278                                               None
# 13285                                               None
# 13291                                               None
# 13303                                               None
# 13312                                               None
# ...                                                  ...
# 15683  <corner><value><stats><corners>1</corners></st...
# 15688  <corner><value><stats><corners>1</corners></st...
# 15697  <corner><value><stats><corners>1</corners></st...
# 15703  <corner><value><stats><corners>1</corners></st...
# 15714  <corner><value><stats><corners>1</corners></st...
#
#                                               possession  B365H  B365D  B365A  \
# 13278                                               None   4.33   3.25   1.80
# 13285                                               None   2.20   3.40   3.20
# 13291                                               None   1.40   4.50   8.00
# 13303                                               None   1.25   5.50  12.00
# 13312                                               None   2.30   3.25   2.80
# ...                                                  ...    ...    ...    ...
# 15683  <possession><value><comment>44</comment><stats...   2.20   3.50   3.10
# 15688  <possession><value><comment>63</comment><stats...   4.33   4.33   1.67
# 15697  <possession><value><comment>45</comment><stats...   2.00   3.75   3.40
# 15703  <possession><value><comment>53</comment><stats...   2.05   3.60   3.30
# 15714  <possession><value><comment>48</comment><stats...   4.00   3.75   1.83
#
#         BWH   BWD    BWA   IWH  IWD    IWA   LBH  LBD   LBA   PSH   PSD   PSA  \
# 13278  3.80  3.40   1.80  3.90  3.3   1.75  3.75  3.3   1.8   NaN   NaN   NaN
# 13285  2.00  3.30   3.35  2.20  3.2   2.75  2.00  3.2   3.2   NaN   NaN   NaN
# 13291  1.45  3.75   6.35  1.45  3.8   5.40  1.44  3.6   6.5   NaN   NaN   NaN
# 13303  1.25  5.00  10.00  1.20  5.0  10.00  1.22  5.0  10.0   NaN   NaN   NaN
# 13312  2.30  3.35   2.70  2.30  3.2   2.50  2.25  3.4   2.6   NaN   NaN   NaN
# ...     ...   ...    ...   ...  ...    ...   ...  ...   ...   ...   ...   ...
# 15683  2.20  3.60   2.85  2.20  3.3   2.90  2.20  3.6   3.1  2.18  3.78  3.32
# 15688  4.75  3.90   1.62  4.80  3.6   1.60  4.33  4.0   1.7  4.69  4.18  1.75
# 15697  1.91  3.60   3.60  1.90  3.5   3.30  1.95  3.6   3.5  2.01  3.79  3.78
# 15703  2.05  3.60   3.20  2.00  3.4   3.20  2.00  3.6   3.4  2.07  3.80  3.58
# 15714  3.90  3.50   1.85  3.80  3.5   1.80  4.00  3.8   1.8  4.17  3.87  1.90
#
#         WHH   WHD    WHA   SJH   SJD    SJA   VCH   VCD    VCA   GBH   GBD  \
# 13278  4.20  3.40   1.70  4.75  3.50   1.73  4.35  3.40   1.70  4.00  3.40
# 13285  2.05  3.40   2.90  2.10  3.40   3.25  2.25  3.30   2.75  2.10  3.25
# 13291  1.40  3.75   7.00  1.44  3.75   7.00  1.45  3.80   6.50  1.47  4.00
# 13303  1.25  5.00  10.00  1.22  5.50  13.00  1.22  5.00  11.00  1.25  5.00
# 13312  2.15  3.30   2.80  2.50  3.25   2.63  2.25  3.40   2.65  2.35  3.30
# ...     ...   ...    ...   ...   ...    ...   ...   ...    ...   ...   ...
# 15683  2.20  3.60   2.80   NaN   NaN    NaN  2.20  3.75   3.00   NaN   NaN
# 15688  4.00  4.20   1.67   NaN   NaN    NaN  4.60  4.33   1.70   NaN   NaN
# 15697  1.91  3.75   3.30   NaN   NaN    NaN  1.95  3.75   3.70   NaN   NaN
# 15703  2.00  3.75   3.00   NaN   NaN    NaN  2.05  3.80   3.50   NaN   NaN
# 15714  3.75  3.60   1.83   NaN   NaN    NaN  4.10  3.90   1.83   NaN   NaN
#
#          GBA   BSH   BSD    BSA
# 13278   1.80  4.33  3.30   1.73
# 13285   3.25  2.20  3.30   2.88
# 13291   5.75  1.50  3.75   6.00
# 13303  10.00  1.25  5.00  10.00
# 13312   2.80  2.30  3.30   2.75
# ...      ...   ...   ...    ...
# 15683    NaN   NaN   NaN    NaN
# 15688    NaN   NaN   NaN    NaN
# 15697    NaN   NaN   NaN    NaN
# 15703    NaN   NaN   NaN    NaN
# 15714    NaN   NaN   NaN    NaN
#
# [272 rows x 115 columns]

# %% [markdown]
# [Terug naar het begin](#begin)

# %% [markdown]
# ## Eigen functies; Statistieken per seizoen bepalen <a name='define1'></a>

# %% [markdown]
# Hieronder zijn 4 functies gedefineerd:
#
#     id_zoeker
#     punten
#     statistiek
#     ranglijst
# De uitleg van alle functies staat omschreven in de docstrings

# %% [markdown]
# ### id_zoeker <a name='id_zoeker'></a>

# %%
def id_zoeker(club):
    """
    Deze functie haalt het ID-nummer van de gegeven club op
    
    Parameters
    ----------
    club : str 
        De volledige naam van de club, waarvan je het ID wilt weten
    
    Returns
    ----------
    id : integer
        Het ID-nummer van de gekozen club
        
    """
    
    #Filteren
    id = team[team['team_long_name'] == club].iloc[0,1]
    return id

# %% [markdown]
# [Terug naar het begin](#begin)

# %% [markdown]
# ### punten <a name='punten'></a>

# %%
def punten(club, seizoen):
    """
    Deze functie maakt, op basis van een club en een seizoen, 2 kolommen aan. Eén over het aantal punten en één over 
    of de wedstrijd thuis of uit was voor het gekozen team.
    
    Parameters
    ----------
    club : str 
        De volledige naam van de club, waarvan je wilt weten hoeveel er gescoord is
    
    seizoen : str
        Het speel seizoen waar je de data van wilt weten
    
    Returns
    ----------
    wed : Pandas DataFrame
        Een dataframe gebaseerd op match, waarbij alleen de data van de aangegeven club en seizoen wordt getoond
    
    """
    
    #Aanmaken van een nieuwe gefilterde dataset
    team_id = id_zoeker(club)
    wed = match[((match['home_team_api_id'] == team_id) | (match['away_team_api_id'] == team_id)) & (match['season'] == seizoen)]
    
    #Beginnen van een list comprehension om de lijsten te vullen
    punten_ = [3 if row['home_team_api_id'] == team_id and row['home_team_goal'] > row['away_team_goal']
           else 1 if row['home_team_api_id'] == team_id and row['home_team_goal'] == row['away_team_goal']
           else 0 if row['home_team_api_id'] == team_id
           else 3 if row['away_team_goal'] > row['home_team_goal']
           else 1 if row['away_team_goal'] == row['home_team_goal']
           else 0 for _, row in wed.iterrows()]

    tu = ['thuis' if row['home_team_api_id'] == team_id else 'uit' for _, row in wed.iterrows()]
        
    #Aanmaken van copy en 2 nieuwe kolommen
    wed = wed.copy()
    wed.loc[:, 'punten'] = punten_
    wed.loc[:, 'thuis / uit'] = tu
    return wed

# %% [markdown]
# [Terug naar het begin](#begin)

# %% [markdown]
# ### statistiek <a name='statistiek'></a>

# %%
def statistiek(club, seizoen):
    """
    Deze functie laat de statistieken zien over de gegeven club in het gegeven seizoen. 
    
    Parameters
    ----------
    club : str 
        De volledige naam van de club, waarvan je de statistieken wilt weten
    
    seizoen : str
        Het speel seizoen waar je de data van wilt weten
    
    Returns
    ----------
    df : Pandas DataFrame
        Een dataframe waarin de naam, het aantal wedstrijden, het aantal punten, het gemiddelde aantal punten 
        per wedstrijd en de winst percentages staan
    
    """
    
    #Aanmaken van 2 aparte dataframes voor percentages
    t = punten(club, seizoen)[punten(club, seizoen)['thuis / uit'] == 'thuis']
    u = punten(club, seizoen)[punten(club, seizoen)['thuis / uit'] == 'uit']
    
    #Maken van een list met alle benodigde data voor het dataframe 
    stats = [[club,
            seizoen,
            len(punten(club, seizoen)),
            sum(punten(club, seizoen)['punten']),
            round(sum(punten(club, seizoen)['punten'] / len(punten(club, seizoen)['punten'])), 2),
            round(t[t['punten'] == 3]['punten'].count() / t['punten'].count() * 100, 2),
            round(t[t['punten'] == 1]['punten'].count() / t['punten'].count() * 100, 2),
            round(t[t['punten'] == 0]['punten'].count() / t['punten'].count() * 100, 2),
            round(u[u['punten'] == 3]['punten'].count() / u['punten'].count() * 100, 2),
            round(u[u['punten'] == 1]['punten'].count() / u['punten'].count() * 100, 2),
            round(u[u['punten'] == 0]['punten'].count() / u['punten'].count() * 100, 2)]]
    
    #Maken van het dataframe
    df = pd.DataFrame(stats, columns =['team',
                                       'seizoen',
                                       'wedstrijden', 
                                       'punten',
                                       'gemiddeld_punten',
                                       'thuis_win%',
                                       'thuis_gelijk%',
                                       'thuis_verlies%',
                                       'uit_win%',
                                       'uit_gelijk%',
                                       'uit_verlies%'])
       
    return df

# %% [markdown]
# [Terug naar het begin](#begin)

# %% [markdown]
# ### ranglijst <a name='ranglijst'></a>

# %%
load_screen = ["Welcome to this journey!..............................................",    
                       "Preparing to load dataset.............................................",    
                       "Checking for missing files...............................................",    
                       "Initializing data structures................................................",    
                       "Setting up parameters.....................................................",    
                       "Loading feature vectors................................................",    
                       "Applying pre-processing steps......................................",    
                       "Filtering out invalid samples.............................................",    
                       "Compiling statistics.......................................................",    
                       "Normalizing data...........................................................",    
                       "Building training and test sets..........................................",    
                       "Cross-validating models.................................................",   
                       "Fine-tuning hyperparameters..........................................",    
                       "Evaluating performance metrics....................................",    
                       "The dataset is almost loaded!........................................"]

def ranglijst(league_naam, seizoen):
    """
    Deze functie laat de ranglijst zien over de gegeven league in het gegeven seizoen. 
    
    Parameters
    ----------
    league_naam : str 
        De naam van de league waarvan je de ranglijst wilt bepalen
    
    seizoen : str
        Het speel seizoen waar je de data van wilt weten
    
    Returns
    ----------
    df : Pandas DataFrame
        Een dataframe waarin de data van het gegeven seizoen staat op volgorde van de behaalde punten
        
    """
    
    #Filteren voor het maken van een lijst met alle team namen in een league
    league_id = league[league['name']== league_naam].iloc[0,1]
    seizoen_filter = match[match['season'] == seizoen]
    team_ids = set(list(seizoen_filter[seizoen_filter['league_id'] == league_id]['home_team_api_id']))
    team_ids = list(team_ids)
    
    #Maken van een lijst met alle team namen in een league
    team_names = []
    for i in team_ids:
        team_names.append(team[team['team_api_id'] == i].iloc[0,3])
    
    #Aanmaken dataframe voor gebruik    
    df = statistiek(team_names[0],seizoen)

    #Loopen over de list met team namen om het dataframe vol te zetten
    print('stats season', seizoen, 'from', league_naam)
    for i in range(1, len(team_names)):
        df = pd.concat([df, statistiek(team_names[i], seizoen)])
        print(str(round(100/(len(team_names)+1)*i,2))+'%', load_screen[(i-1)%15], end = '\r')
    print('100.0% This adventure was brought to you by Group 3B.........')
    
    #Sorteren van het dataframe op basis van behaalde punten
    df = df.sort_values(by='punten', ascending = False).set_index('team')
    
    return df

# %% [markdown]
# [Terug naar het begin](#begin)

# %% [markdown]
# ## Het runnen van de functies <a name='run1'></a>
# Hieronder worden de functies statistiek en ranglijst uitgevoerd:

# %%
statistiek('Heracles Almelo', '2009/2010')
# Out:
#               team    seizoen  wedstrijden  punten  gemiddeld_punten  \
# 0  Heracles Almelo  2009/2010           34      56              1.65
#
#    thuis_win%  thuis_gelijk%  thuis_verlies%  uit_win%  uit_gelijk%  \
# 0       64.71           5.88           29.41     35.29        23.53
#
#    uit_verlies%
# 0         41.18

# %%
ranglijst('Netherlands Eredivisie', '2009/2010')
# Out:
# stats season 2009/2010 from Netherlands Eredivisie
# 100.0% This adventure was brought to you by Group 3B...............................
#                     seizoen  wedstrijden  punten  gemiddeld_punten  \
# team
# FC Twente         2009/2010           34      86              2.53
# Ajax              2009/2010           34      85              2.50
# PSV               2009/2010           34      78              2.29
# Feyenoord         2009/2010           34      63              1.85
# AZ                2009/2010           34      62              1.82
# Heracles Almelo   2009/2010           34      56              1.65
# FC Utrecht        2009/2010           34      53              1.56
# FC Groningen      2009/2010           34      49              1.44
# Roda JC Kerkrade  2009/2010           34      47              1.38
# NAC Breda         2009/2010           34      46              1.35
# SC Heerenveen     2009/2010           34      37              1.09
# VVV-Venlo         2009/2010           34      35              1.03
# N.E.C.            2009/2010           34      33              0.97
# Vitesse           2009/2010           34      32              0.94
# ADO Den Haag      2009/2010           34      30              0.88
# Sparta Rotterdam  2009/2010           34      26              0.76
# Willem II         2009/2010           34      23              0.68
# RKC Waalwijk      2009/2010           34      15              0.44
#
#                   thuis_win%  thuis_gelijk%  thuis_verlies%  uit_win%  \
# team
# FC Twente              94.12           5.88            0.00     64.71
# Ajax                   94.12           5.88            0.00     64.71
# PSV                    76.47          23.53            0.00     58.82
# Feyenoord              52.94          35.29           11.76     47.06
# AZ                     64.71          11.76           23.53     47.06
# Heracles Almelo        64.71           5.88           29.41     35.29
# FC Utrecht             47.06          41.18           11.76     35.29
# FC Groningen           52.94          17.65           29.41     29.41
# Roda JC Kerkrade       52.94          17.65           29.41     29.41
# NAC Breda              47.06          29.41           23.53     23.53
# SC Heerenveen          41.18          23.53           35.29     23.53
# VVV-Venlo              41.18          35.29           23.53      5.88
# N.E.C.                 29.41          29.41           41.18     17.65
# Vitesse                29.41          29.41           41.18     17.65
# ADO Den Haag           23.53          17.65           58.82     17.65
# Sparta Rotterdam       29.41          23.53           47.06      5.88
# Willem II              35.29          11.76           52.94      5.88
# RKC Waalwijk           23.53           0.00           76.47      5.88
#
#                   uit_gelijk%  uit_verlies%
# team
# FC Twente               23.53         11.76
# Ajax                    17.65         17.65
# PSV                     29.41         11.76
# Feyenoord               35.29         17.65
# AZ                      17.65         35.29
# Heracles Almelo         23.53         41.18
# FC Utrecht              23.53         41.18
# FC Groningen            23.53         47.06
# Roda JC Kerkrade        11.76         58.82
# NAC Breda               29.41         47.06
# SC Heerenveen            0.00         76.47
# VVV-Venlo               29.41         64.71
# N.E.C.                  23.53         58.82
# Vitesse                 17.65         64.71
# ADO Den Haag            35.29         47.06
# Sparta Rotterdam        23.53         70.59
# Willem II                0.00         94.12
# RKC Waalwijk             0.00         94.12

# %% [markdown]
# #### Einde Sprint 2

# %% [markdown]
# [Terug naar het begin](#begin)

# %% [markdown]
# # Sprint 3 <a name='spr3'></a>

# %% [markdown]
# Voordat we aan de SQL functies beginnen, word er een decorator gemaakt om queries met SQL code te kunnen lezen.

# %%
def sql_lezer(func):
    """
    Een decorator die een functie met een query omzet tot een Pandas DataFrame

    Parameters
    ----------
    func: Python Function
        Een python function die een query bevat

    Returns
    -------
    df : Pandas DataFrame
        Een DataFrame met het resultaat van de query.
    """
    
    @wraps(func)
    def wrapper(*args, **kwargs):
        query = func(*args, **kwargs)
        
        #Aanmaken van try om te proberen de SQL query in te lezen.
        try:
            df = pd.read_sql(query, connect)
            return df
        
        #Aanmaken van except om error's bij het inlezen niet de 'run all' van jupyter te laten stoppen, deze geeft het type melding als tekst weer.
        except Exception as e:
            print(f"Error: {e}")
            return None
        
    return wrapper

# %% [markdown]
# [Terug naar het begin](#begin)

# %% [markdown]
# ## Eigen functies: Prestaties van Heracles Almelo <a name='prestatie'></a>

# %% [markdown]
# In de volgende cellen code worden de functies gemaakt om te kijken naar de prestaties van ons team, Heracles Almelo. Eerst wordt er bekeken hoeveel wedstrijden er in elk seizoen zijn gespeeld.

# %% [markdown]
# ### wedstrijden

# %%
@sql_lezer
def wedstrijden(team_id):
    """
    Haalt het aantal gespeelde wedstrijden op van een bepaald team voor elk seizoen.

    Parameters
    ----------
    team_id : int
        Het team ID van het team waarvan het aantal gespeelde wedstrijden wordt opgehaald.

    Returns
    -------
    query : str
        Een SQL-query die het aantal gespeelde wedstrijden door het opgegeven team voor elk seizoen toont, 
        met de kolommen seizoen en Games_played. De query wordt gelezen en veranderd in een dataframe door
        de decorator: sql_lezer.
    """
    
    query = f"""
        SELECT season
                    , COUNT(DISTINCT(match_api_id)) AS Games_played
            FROM match
        
        WHERE (home_team_api_id = {team_id}) OR (away_team_api_id = {team_id})
        
        GROUP BY season
    """
    return query

# %% [markdown]
# [Terug naar het begin](#begin)

# %% [markdown]
# ### wedstrijden_2010

# %% [markdown]
# Vervolgens wordt er gekeken naar het aantal gespeelde wedstrijden in het jaar 2010.

# %%
@sql_lezer
def wedstrijden_2010(team_id):
    """
    Haalt het aantal gespeelde wedstrijden op van een bepaald team in het jaar 2010.

    Parameters
    ----------
    team_id : int
        Het team ID van het team waarvan het aantal gespeelde wedstrijden wordt opgehaald.

    Returns
    -------
    query : str
        Een SQL-query die het aantal gespeelde wedstrijden door het opgegeven team in het jaar 2010 toont, 
        met de kolommen seizoen en Games_played. De query wordt gelezen en veranderd in een dataframe door
        de decorator: sql_lezer.
    """
    
    query = f"""
        SELECT season
                    , COUNT(DISTINCT(match_api_id)) AS Games_played
            FROM match
        
        WHERE ((home_team_api_id = {team_id}) OR (away_team_api_id = {team_id})) 
        And (date BETWEEN '2010-01-01 00:00:00' AND '2010-12-31 00:00:00' )
        
        GROUP BY season

    """
    return query

# %% [markdown]
# [Terug naar het begin](#begin)

# %% [markdown]
# ### maak_tabel

# %% [markdown]
# Hieronder wordt er een tabel aangemaakt om bij de volgende opgaven te gebruiken. Deze tabel wordt gebruikt om het aantal punten per seizoen per competitie te tonen.

# %%
@sql_lezer
def maak_tabel(league_id):
    """
    Haalt de punten op van elk team per seizoen in de opgegeven competitie. Deze waarden worden vervolgens in een nieuwe tabel gezet.

    Parameters
    ----------
    league_id : int
        Het ID van de competitie waarvan de punten van elk team per seizoen worden opgehaald, ook wordt de plaats in de competities getoond.

    Returns
    -------
     query : str
        Een SQL-query die de punten van elk team per seizoen in de opgegeven competitie toont,
        met de kolommen league_id, season, Team_ID, Home_Points, Away_Points, Total_Points en Rank.
        De resultaten zijn gesorteerd op seizoen en totale punten in aflopende volgorde. De query wordt gelezen
        en toegepast door de decorator: sql_lezer.
    """
    
    query = f""" 
        CREATE TEMP TABLE pps_{league_id} AS
        SELECT h.league_id
                    , h.season
                    , h.Team_ID AS team_api_id
                    , h.Points AS punten_thuis
                    , a.Points AS punten_uit
                    , (h.Points + a.Points) AS punten_totaal
                    , ROW_NUMBER() OVER (PARTITION BY h.season ORDER BY (h.Points + a.Points) DESC) AS rang_seizoen
                
            FROM (SELECT league_id
                                    , season
                                    , home_team_api_id AS Team_ID
                                    , SUM(CASE WHEN (home_team_goal > away_team_goal) THEN 3
                                                          WHEN (home_team_goal = away_team_goal) THEN 1
                                                          WHEN (home_team_goal < away_team_goal) THEN 0
                                                          END) AS Points
                            FROM match
                            WHERE league_id = {league_id}
                            GROUP BY season
                                            , Team_ID) AS h
                        
        JOIN (SELECT league_id
                                , season
                                , away_team_api_id AS Team_ID
                                , SUM(CASE WHEN (away_team_goal > home_team_goal) THEN 3
                                                      WHEN (away_team_goal = home_team_goal) THEN 1
                                                      WHEN (away_team_goal < home_team_goal) THEN 0
                                                      END) AS Points
                    FROM match
                    WHERE league_id = {league_id}
                    GROUP BY season
                                    , Team_ID) AS a 
            ON h.season = a.season AND h.Team_ID = a.Team_ID
                    
        ORDER BY h.season, punten_totaal DESC;
    """
    return query.strip()

# %% [markdown]
# [Terug naar het begin](#begin)

# %% [markdown]
# ### punten_per_seizoen

# %% [markdown]
# Nu wordt de functie punten_per_seizoen aangemaakt, die de aangemaakte tabel toont.

# %%
@sql_lezer 
def punten_per_seizoen(league_id):
    """
    Deze functie toont de tabel met het league_id waarmee de punten tabel is aangemaakt
    
    Parameters
    ----------
    league_id : int
        Het ID van de competitie waarvan de tabel die is aangemaakt met maak_tabel() is aangemaakt.

    Returns
    ---------
     query : str
        Een SQL-query die is gemaakt met maak_tabel(). Deze bevat de volgende kolommen:
        league_id, season, Team_ID, Home_Points, Away_Points, Total_Points en Rank.
        De query wordt gelezen en veranderd in een dataframe door de decorator: sql_lezer.
    
    """
    
    query = f"""
        SELECT *
            FROM pps_{league_id}
    """
    return query

# %% [markdown]
# [Terug naar het begin](#begin)

# %% [markdown]
# ### plaats_team

# %% [markdown]
# Als laatste wordt in de competitie gekeken naar plaats van Heracles Almelo per seizoen.

# %%
@sql_lezer
def plaats_team(league_id, team_id):
    """
    Deze functie toont de tabel met het league_id waarmee de punten tabel is aangemaakt, deze is gefilterd op het aangegeven team_id.
    
    Parameters
    ----------
    league_id : int
        Het ID van de competitie waarvan de tabel die is aangemaakt met maak_tabel() is aangemaakt.

    Returns
    ---------
     query : str
        Een SQL-query die is gemaakt met maak_tabel(), gefilterd op het gegeven team_id. 
        Deze bevat de volgende kolommen: league_id, season, Team_ID, Home_Points, Away_Points, Total_Points en Rank.
        De query wordt gelezen en veranderd in een dataframe door de decorator: sql_lezer.
    """
    
    query = f"""
    SELECT *
        FROM pps_{league_id}
        
        WHERE team_api_id = {team_id}
    """
    return query

# %% [markdown]
# [Terug naar het begin](#begin)

# %% [markdown]
# ## Bekijken van de prestaties <a name='prebekijk'></a>

# %% [markdown]
# In de onderstaande cellen zijn de resultaten in een cluster bij elkaar te vinden, de resultaten zijn afkomend van de vorige 5 eigen functies. Hierbij is voor het maken van de tabel pandas gebruikt en voor het selecteren word SQL gebruikt.

# %%
wedstrijden(9791)
# Out:
#       season  Games_played
# 0  2008/2009            34
# 1  2009/2010            34
# 2  2010/2011            34
# 3  2011/2012            34
# 4  2012/2013            34
# 5  2013/2014            34
# 6  2014/2015            34
# 7  2015/2016            34

# %%
wedstrijden_2010(9791)
# Out:
#       season  Games_played
# 0  2009/2010            16
# 1  2010/2011            18

# %%
maak_tabel(13274)
# Out:
# Error: 'NoneType' object is not iterable

# %% [markdown]
# De functie maak_tabel geeft als het goed is een Error 'NoneType' object op. Dit komt omdat de decorator nodig was om de functie te laten werken. Echter kan de decorator geen dataframe aanmaken doordat er een tabel wordt aangemaakt om te kunnen gebruiken voor de volgende twee functies.

# %%
punten_per_seizoen(13274)
# Out:
#      league_id     season  team_api_id  punten_thuis  punten_uit  \
# 0        13274  2008/2009        10229            43          37
# 1        13274  2008/2009         8611            40          29
# 2        13274  2008/2009         8593            42          26
# 3        13274  2008/2009         8640            37          28
# 4        13274  2008/2009        10228            38          22
# ..         ...        ...          ...           ...         ...
# 139      13274  2015/2016         9803            15          19
# 140      13274  2015/2016        10218            17          13
# 141      13274  2015/2016         8525            15          14
# 142      13274  2015/2016         8526            15           8
# 143      13274  2015/2016         7788            11           7
#
#      punten_totaal  rang_seizoen
# 0               80             1
# 1               69             2
# 2               68             3
# 3               65             4
# 4               60             5
# ..             ...           ...
# 139             34            14
# 140             30            15
# 141             29            16
# 142             23            17
# 143             18            18
#
# [144 rows x 7 columns]

# %%
plaats_team(13274, 9791)
# Out:
#    league_id     season  team_api_id  punten_thuis  punten_uit  punten_totaal  \
# 0      13274  2008/2009         9791            25           7             32
# 1      13274  2009/2010         9791            34          22             56
# 2      13274  2010/2011         9791            37          12             49
# 3      13274  2011/2012         9791            25          15             40
# 4      13274  2012/2013         9791            24          14             38
# 5      13274  2013/2014         9791            17          20             37
# 6      13274  2014/2015         9791            19          18             37
# 7      13274  2015/2016         9791            32          19             51
#
#    rang_seizoen
# 0            14
# 1             6
# 2             8
# 3            12
# 4            13
# 5            14
# 6            13
# 7             6

# %% [markdown]
# [Terug naar het begin](#begin)

# %% [markdown]
# ## Eigen functies: Onderzoek teameigenschappen <a name='team'></a>

# %% [markdown]
# Nu is het tijd om te kijken naar welke impact verschillende teameigenschappen hebben voor het hoger scoren van punten. Hiervoor worden er eerst wat DataFrames aangepast en aangemaakt.

# %% [markdown]
# ### kolom_seizoen

# %% [markdown]
# Voordat er begonnen wordt met het onderzoek word er, met behulp van een eigen functie, een kolom aangemaakt om twee dataframes te kunnen mergen.

# %%
def kolom_seizoen(df, col):
    """
    Geeft een lijst van seizoenen terug op basis van de maanden in een kolom van een pandas DataFrame.

    Parameters:
    -----------------
    df: Pandas DataFrame
        Het DataFrame waaruit de maanden worden gehaald
        
    col: str
        De naam van de kolom waaruit de maanden worden gehaald

    Returns:
    ------------
    season_list: list
        Een lijst van seizoenen in de vorm 'jaar/jaar', waarbij het jaar eindigt in juli.
    """
    
    #Aanmaken van een lege lijst om te gaan vullen 
    season_list = []
    
    #For-loop om de maanden om te zetten in seizoenen.
    for datum in df[col]:
        maand = datum[5:7]
        maand = int(maand)
        if maand > 7:
            season_list.append(datum[0:4] + '/' + str(int(datum[0:4]) + 1))
        else:
            season_list.append(str(int(datum[0:4]) - 1) + '/' + datum[0:4])
    
    return season_list

team_attributes['season'] = kolom_seizoen(team_attributes, 'date')

# %% [markdown]
# ### df_punten

# %% [markdown]
# Nu wordt er een dataframe gemaakt waarbij het aantal behaalde punten per team (van elke competitie) per seizoen getoond wordt.

# %%
def df_punten(df, seizoen):
    """
    Maakt het dataframe df_punten aan voor een merge. Hierin bevinden zich de kolommen: season, team_api_id en punten.

    Parameters:
    -----------------
    df: pandas.DataFrame
        Het pandas dataframe dat je wilt gebruiken
    
    seizoen : str
        De jaartallen van het seizoen die bekeken wordt.

    Returns:
    ------------
    df_punten : Pandas DataFrame
        Een pandas DataFrame waarin het aangegeven seizoen, het team_id van de teams en het aantal behaalde punten staan.
    """
        
    #Zorgen dat het juiste seizoen wordt gekozen
    match_temp = df[df['season'] == seizoen].reset_index(drop=True)
    
    #Maak 2 lijsten voor de behaalde thuis en uit punten
    home_points = [3 if h > a else 1 if h == a else 0 for h, a in zip(match_temp['home_team_goal'], match_temp['away_team_goal'])]
    away_points = [3 if a > h else 1 if a == h else 0 for h, a in zip(match_temp['home_team_goal'], match_temp['away_team_goal'])]
    
    #Maak een lijst met daarin alle data die nodig is voor bij de merge (De ' \ ' is om door te gaan op de volgende regel)
    data = [[match_temp['season'][i], match_temp['home_team_api_id'][i], home_points[i]] for i in range(len(match_temp))] + \
               [[match_temp['season'][i], match_temp['away_team_api_id'][i], away_points[i]] for i in range(len(match_temp))]
    
    #Maken van de dataframe df_points
    df_punten = pd.DataFrame(data, columns=['season','team_api_id','punten'])

    #Groepeer op seizoen en team_id om de punten op te tellen
    df_punten = df_punten.groupby(['season','team_api_id']).sum().reset_index()
    
    return df_punten

# %% [markdown]
# ### get_name

# %% [markdown]
# Met deze functie kan er van elke kolom die een team_api_id bevat een naam gevonden worden, zolang deze naam in de team dataframe te vinden is.

# %%
def get_name(df, col): 
    """
    Zoekt de team namen bij een behorende team ID in de aangegeven kolommen

    Parameters:
    -----------------
        df : pandas.DataFrame
            Het betreffende dataframe waar je de functie op uitvoert
            
        col : str
            De kolomnaam met de team_api_id's
            
    Returns:
    ---------------
        long_names : list 
            Een lijst met de namen van de teams, afhankelijk van de id's
    """
    
    long_names = [(team[team['team_api_id']==i].iloc[0,3]) for i in df[col]]
    return long_names

# %% [markdown]
# ## Het aanmaken van de tabel <a name='kolmaken'></a>

# %% [markdown]
# In de onderstaande cel zal het dataframe team_attributes_points aangemaakt worden. Ook zal er een kolom met de volledige teamnaam worden aangemaakt.

# %%
#merge team_attributes en df_points
team_attributes_points = pd.merge(team_attributes, df_punten(match, '2009/2010'), on=['team_api_id', 'season'])

#pakt de team namen erbij
team_attributes_points['long_name'] = get_name(team_attributes_points,'team_api_id')

#door index te maken en weer wegtehalen worden de kolommen voor aan gezet
team_attributes_points = team_attributes_points.set_index(['long_name','season','punten']).reset_index(drop=False)

#verwijderen kolommen die te veel NaN-waardes hebben of nauwelijks invloed hebben op performance.
#De team_api_id en season kolommen zijn nog aanwezig om de date overzichtelijker te houden, deze hebben nauwelijks invloed op performance.
team_attributes_points = team_attributes_points.drop(['buildUpPlayDribbling', 'id', 'team_fifa_api_id', 'date'],axis=1)

display(team_attributes_points)
# Out:
#                 long_name     season  punten  team_api_id  buildUpPlaySpeed  \
# 0                FC Aarau  2009/2010      23         9930                60
# 1                Aberdeen  2009/2010      41         8485                70
# 2                   Milan  2009/2010      70         8564                45
# 3    Académica de Coimbra  2009/2010      33        10215                30
# 4            ADO Den Haag  2009/2010      30        10217                30
# ..                    ...        ...     ...          ...               ...
# 180  Xerez Club Deportivo  2009/2010      34         9868                30
# 181        BSC Young Boys  2009/2010      77        10192                55
# 182        Zagłębie Lubin  2009/2010      35         8021                55
# 183         Real Zaragoza  2009/2010      41         8394                30
# 184      SV Zulte-Waregem  2009/2010      41        10000                65
#
#     buildUpPlaySpeedClass buildUpPlayDribblingClass  buildUpPlayPassing  \
# 0                Balanced                    Little                  50
# 1                    Fast                    Little                  70
# 2                Balanced                    Little                  30
# 3                    Slow                    Little                  30
# 4                    Slow                    Little                  35
# ..                    ...                       ...                 ...
# 180                  Slow                    Little                  30
# 181              Balanced                    Little                  55
# 182              Balanced                    Little                  60
# 183                  Slow                    Little                  30
# 184              Balanced                    Little                  60
#
#     buildUpPlayPassingClass buildUpPlayPositioningClass  \
# 0                     Mixed                   Organised
# 1                      Long                   Organised
# 2                     Short                   Free Form
# 3                     Short                   Organised
# 4                     Mixed                   Organised
# ..                      ...                         ...
# 180                   Short                   Organised
# 181                   Mixed                   Organised
# 182                   Mixed                   Organised
# 183                   Short                   Free Form
# 184                   Mixed                   Organised
#
#      chanceCreationPassing chanceCreationPassingClass  chanceCreationCrossing  \
# 0                       60                     Normal                      65
# 1                       70                      Risky                      70
# 2                       55                     Normal                      45
# 3                       50                     Normal                      60
# 4                       30                       Safe                      50
# ..                     ...                        ...                     ...
# 180                     45                     Normal                      35
# 181                     55                     Normal                      70
# 182                     30                       Safe                      40
# 183                     50                     Normal                      35
# 184                     60                     Normal                      40
#
#     chanceCreationCrossingClass  chanceCreationShooting  \
# 0                        Normal                      55
# 1                          Lots                      70
# 2                        Normal                      70
# 3                        Normal                      55
# 4                        Normal                      65
# ..                          ...                     ...
# 180                      Normal                      70
# 181                        Lots                      60
# 182                      Normal                      70
# 183                      Normal                      70
# 184                      Normal                      50
#
#     chanceCreationShootingClass chanceCreationPositioningClass  \
# 0                        Normal                      Organised
# 1                          Lots                      Organised
# 2                          Lots                      Free Form
# 3                        Normal                      Organised
# 4                        Normal                      Organised
# ..                          ...                            ...
# 180                        Lots                      Organised
# 181                      Normal                      Organised
# 182                        Lots                      Organised
# 183                        Lots                      Organised
# 184                      Normal                      Organised
#
#      defencePressure defencePressureClass  defenceAggression  \
# 0                 50               Medium                 55
# 1                 60               Medium                 70
# 2                 30                 Deep                 35
# 3                 30                 Deep                 30
# 4                 30                 Deep                 30
# ..               ...                  ...                ...
# 180               45               Medium                 50
# 181               55               Medium                 55
# 182               70                 High                 70
# 183               40               Medium                 30
# 184               70                 High                 60
#
#     defenceAggressionClass  defenceTeamWidth defenceTeamWidthClass  \
# 0                    Press                45                Normal
# 1                   Double                70                  Wide
# 2                    Press                60                Normal
# 3                  Contain                30                Narrow
# 4                  Contain                30                Narrow
# ..                     ...               ...                   ...
# 180                  Press                45                Normal
# 181                  Press                60                Normal
# 182                 Double                70                  Wide
# 183                Contain                45                Normal
# 184                  Press                70                  Wide
#
#     defenceDefenderLineClass
# 0                      Cover
# 1                      Cover
# 2               Offside Trap
# 3               Offside Trap
# 4                      Cover
# ..                       ...
# 180                    Cover
# 181             Offside Trap
# 182                    Cover
# 183             Offside Trap
# 184                    Cover
#
# [185 rows x 24 columns]

# %% [markdown]
# [Terug naar het begin](#begin)

# %% [markdown]
# ## Eigen functies: Visualisaties voor team statistiek <a name='visu1'></a>

# %% [markdown]
# Voor de visualisaties wordt er gezocht naar correlatie tussen het puntenaantal en de teameigenschappen. Eerst worden de functies gemaakt en vervolgens zullen deze functies aangeroepen worden.

# %% [markdown]
# ### heatmap

# %% [markdown]
# Het maken van de heatmap geeft een duidelijk overzicht van de verschillende kolommen met numerieke variablen.

# %%
def heatmap(kolommen, corrnaam, df):
    """
    Deze functie maakt een heatmap aan, gebaseerd op een lijst aan kolommen en een gegeven dataframe
    
    Parameters:
    ---------------
    kolommen : list[str]
        Een lijst met numerieke kolommen waarvoor de correlatie tot 'corrnaam' wordt uitgerekend.
    
    corrnaam : str
        De naam van de kolom waarmee de lijst van kolommen wordt gecorreleerd
        
    df : Pandas DataFrame
        Het DataFrame waar de eerder vernoemde kolommen instaan
        
    Returns:
    ---------------
    None
        Er wordt geen waarde gereturned. Er word een plot gemaakt van de correlatie in vorm van een heatmap.
    """
    
    #Maken van een nieuw dataframe met de gewilde kolommen
    corr = df[kolommen + [corrnaam]]

    #Maken van correlatie df
    corr_hm = corr.corr()
    corr_hm_col = corr_hm[corrnaam]
    corr_hm_fini = corr_hm_col.drop(corrnaam)

    #Plotten van de grafiek
    sns.heatmap(pd.DataFrame(corr_hm_fini.sort_values(ascending=False)), cmap='coolwarm', annot=True)
    return plt.show()

# %% [markdown]
# ### scatterplots

# %% [markdown]
# De scatterplots zijn er om de correlatie nogmaals in beeld te brengen, echter laten de scatterplots het ook nog toe om de categoriale variablen te tonen.

# %%
#Maken van scatterplots voor elke kolom, t.o.v. de punten kolom
def scatterplots(df, kolom):
    """
    Maakt een aantal scatter plots gelijk aan het aantal kolommen in de Dataframe. De scatterplots zijn tegen één specifieke kolom opgezet, om de 
    correlatie te visualiseren.
    
    Parameters:
    ----------------
    df : Pandas DataFrame
        Een pandas DataFrame met kolommen waarvan je de correlaties wilt onderzoeken.
    
    kolom : str
        De naam van de kolom waarmee de correlatie berekend word, ten opzichte van de andere kolommen.
        
    Returns:
    ---------------
    None :
        In plaats van iets te returnen laat de functie meerdere scatterplots zien.
    """    
    #For-loop om elke kolom een eigen scatterplot te geven
    for col in df.columns:
        #if-statement om te voorkomen dat de parameter kolom ook een scatterplot krijgt
        if col != kolom:
            #Zetten van de grootte van de plot
            plt.subplots(figsize=(15, 5))
            
            #Maken en benoemen van de assen van een scatterplot
            plt.scatter(df[col], df[kolom])
            plt.xlabel(col)
            plt.ylabel(kolom)
            plt.title('{} vs. {}'.format(kolom, col))
            plt.show()

# %% [markdown]
# ### boxplots

# %% [markdown]
# Als laatste word er gekeken via boxplots. Boxplots tonen de verdeling van de variablen, waardoor er duidelijker kan worden gekeken naar de variablen. Deze verdeling kan laten zien of er misschien optimale niveau's van aanvals of verdedigings statistieken zijn, in plaats van dat er naar de correlatie wordt gekeken.

# %%
def boxplots(df, kolom):
    """
    Maakt een aantal box plots gelijk aan het aantal kolommen in de Dataframe. De box zijn tegen één specifieke kolom opgezet, om de 
    verdeling t.o.v. die kolom te tonen.
    
    Parameters:
    ----------------
    df : Pandas DataFrame
        Een pandas DataFrame met kolommen waarvan je de verdeling wilt onderzoeken.
    
    kolom : str
        De naam van de kolom waarbij de verdeling bekeken word, ten opzichte van de andere kolommen.
        
    Returns:
    ---------------
    None :
        In plaats van iets te returnen laat de functie meerdere boxplots zien.
    """    
    #For-loop om elke kolom een eigen boxplot te geven
    for col in df.columns:
        #if-statement om te voorkomen dat de kolom-parameter ook een boxplot krijgt
        if col != kolom:
            #Zetten van de grootte van de plot
            plt.subplots(figsize=(15, 5))
            
            #Maken en benoemen van de assen van de boxplots
            sns.boxplot(x=col, y=kolom, data=df, color= 'skyblue')
            plt.xlabel(col)
            plt.ylabel(kolom)
            plt.title('{} vs. {}'.format(kolom, col))
            plt.show()

# %% [markdown]
# ## Tonen van de grafieken <a name='run3'></a>

# %% [markdown]
# Hieronder tonen we van elke functie de resulterende grafieken. Ook word er een nieuw df en een list aangemaakt om deze te gebruiken voor de visualisaties.

# %%
#Relevante kolommen met de hand kiezen voor correlatie (numerieke kolommen), kolommen met te veel missende waardes zijn ook weggelaten.
kolom_num = ['buildUpPlaySpeed', 'buildUpPlayPassing',
                   'chanceCreationPassing', 'chanceCreationCrossing', 'chanceCreationShooting',
                   'defencePressure', 'defenceAggression', 'defenceTeamWidth']

# %%
heatmap(kolom_num, 'punten', team_attributes_points)

# %% [markdown]
# Bij de heatmap valt er te zien dat de correlaties niet erg hoog zijn, door de scatterplots en boxplots wordt er gehoopt om een beter begrip te krijgen over welke waardes impact hebben op het aantal gescoorde punten.

# %%
#Weghalen van bepaalde kolommen die geen impact hebben op het aantal punten
tap = team_attributes_points.copy()
tap = tap.drop(['long_name', 'season', 'team_api_id'], axis = 1)

# %%
scatterplots(tap, 'punten')

# %%
boxplots(tap, 'punten')

# %% [markdown]
# Zo als te zien is uit de verschillende plots, valt er niet op 1 statistiek te drukken. Verschillende statistieken tonen betere resultaten op verschillende getallen, van zowel hoog, middel en laag. Dit laat zien dat de correlatie misschien niet hoog is wegens de brede spreiding van statistieken. De teameigenschappen zouden verder onderzocht moeten worden om goed te kunnen vertellen welke combinaties in statistiek beter werken dan anderen.

# %% [markdown]
# [Terug naar het begin](#begin)

# %% [markdown]
# # Sprint 4 <a name='spr4'></a>

# %% [markdown]
# ## Eigen functie: Statistieken per speler <a name='spelerstat'></a>

# %% [markdown]
# Om een beeld te krijgen van hoe goed elke speler is, is er een DataFrame aangemaakt waarin de gemiddelde statistieken van elke speler in de dataset is te vinden.

# %%
def spelers(method):
    """
    Deze functie maakt op basis van het dataframe met de spelersattributen een nieuw dataframe waarin voor iedere speler slechts één rij is 
    met daarin het gemiddelde van alle numerieke ratings.
    
    Parameters:
    -----------
    method : str
        De methode om de groupby en de berekening te maken, voor als men de mediaan o.i.d. wilt bekijken van de getallen
    
    Returns:
    --------
    spelers : pandas.DataFrame
        Geeft een aangepast dataframe met kolommen met gemiddelden van alle numerieke ratings.
    """
    
    #Eerst wordt er gemerged
    spelers = player.merge(player_attributes, on= ['player_api_id', 'player_fifa_api_id'])
    
    #Dan worden er kolommen gedropped en wordt er grgrouped op de gegeven methode
    spelers = spelers.drop(['player_fifa_api_id', 'id_x', 'id_y', 'birthday'], axis= 1)
    spelers = spelers.groupby('player_name').agg(method).round(2)
    
    #Hier wordt een extra dataframe gemaakt om 3 kolommen niet mee te nemen in de berekening.
    rating = spelers.drop(['player_api_id', 'height', 'weight'], axis= 1).agg(method, axis= 1).round(2)
    spelers[f'{method}_rating'] = rating
    
    return spelers

# %%
#Hier wordt de functie uitgevoerd
spelers('mean')
# Out:
#                              player_api_id  height  weight  overall_rating  \
# player_name
# Aaron Appindangoye                505942.0  182.88   187.0           63.60
# Aaron Cresswell                   155782.0  170.18   146.0           66.97
# Aaron Doran                       162549.0  170.18   163.0           67.00
# Aaron Galindo                      30572.0  182.88   198.0           69.09
# Aaron Hughes                       23780.0  182.88   154.0           73.24
# ...                                    ...     ...     ...             ...
# Zsolt Low                          36491.0  180.34   154.0           67.57
# Zurab Khizanishvili                35506.0  185.42   172.0           70.75
# Zvjezdan Misimovic                 39902.0  180.34   176.0           80.00
# de Oliveira Cleber Monteiro        11833.0  182.88   170.0           66.11
# dos Santos Fabio Junior            38804.0  175.26   174.0           66.75
#
#                              potential  crossing  finishing  heading_accuracy  \
# player_name
# Aaron Appindangoye               67.60     48.60      43.60             70.60
# Aaron Cresswell                  74.48     70.79      49.45             52.94
# Aaron Doran                      74.19     68.12      57.92             58.69
# Aaron Galindo                    70.78     57.22      26.26             69.26
# Aaron Hughes                     74.68     45.08      38.84             73.04
# ...                                ...       ...        ...               ...
# Zsolt Low                        72.86     63.14      44.57             59.86
# Zurab Khizanishvili              78.12     46.75      43.00             79.00
# Zvjezdan Misimovic               81.70     78.20      72.60             57.40
# de Oliveira Cleber Monteiro      67.56     53.11      56.56             63.00
# dos Santos Fabio Junior          73.00     61.00      64.75             62.00
#
#                              short_passing  volleys  dribbling  curve  \
# player_name
# Aaron Appindangoye                   60.60    43.60      50.60  44.60
# Aaron Cresswell                      62.27    29.15      61.09  61.88
# Aaron Doran                          65.12    54.27      69.04  60.19
# Aaron Galindo                        64.70    47.78      55.57  37.78
# Aaron Hughes                         64.76    32.08      50.60  45.48
# ...                                    ...      ...        ...    ...
# Zsolt Low                            66.86    57.00      66.86  60.00
# Zurab Khizanishvili                  58.88    59.00      36.00  29.00
# Zvjezdan Misimovic                   85.50    77.00      83.00  86.00
# de Oliveira Cleber Monteiro          66.44    45.78      55.56  30.78
# dos Santos Fabio Junior              63.00    59.00      68.50  60.00
#
#                              free_kick_accuracy  long_passing  ball_control  \
# player_name
# Aaron Appindangoye                        38.60         63.60         48.60
# Aaron Cresswell                           62.12         63.24         61.79
# Aaron Doran                               55.62         60.46         68.62
# Aaron Galindo                             40.39         60.83         63.17
# Aaron Hughes                              26.36         56.84         60.16
# ...                                         ...           ...           ...
# Zsolt Low                                 52.57         58.29         68.14
# Zurab Khizanishvili                       41.38         50.62         62.00
# Zvjezdan Misimovic                        74.20         79.00         85.20
# de Oliveira Cleber Monteiro               49.11         58.33         66.33
# dos Santos Fabio Junior                   59.00         51.50         67.50
#
#                              acceleration  sprint_speed  agility  reactions  \
# player_name
# Aaron Appindangoye                  60.00         64.00    59.00      46.60
# Aaron Cresswell                     76.00         74.94    75.24      67.85
# Aaron Doran                         75.54         77.50    77.62      50.35
# Aaron Galindo                       50.22         52.83    62.83      58.22
# Aaron Hughes                        51.12         54.08    50.76      69.40
# ...                                   ...           ...      ...        ...
# Zsolt Low                           71.00         72.14    59.00      69.14
# Zurab Khizanishvili                 65.00         61.50    56.00      62.75
# Zvjezdan Misimovic                  62.50         65.70    78.20      75.60
# de Oliveira Cleber Monteiro         63.33         61.67    60.89      61.44
# dos Santos Fabio Junior             73.25         72.00    76.00      76.75
#
#                              balance  shot_power  jumping  stamina  strength  \
# player_name
# Aaron Appindangoye             65.00       54.60    58.00    54.00     76.00
# Aaron Cresswell                84.73       65.91    75.30    72.88     51.76
# Aaron Doran                    80.73       62.81    67.31    70.92     70.08
# Aaron Galindo                  44.09       64.87    70.78    55.43     78.70
# Aaron Hughes                   64.16       47.08    77.84    66.48     73.80
# ...                              ...         ...      ...      ...       ...
# Zsolt Low                      72.00       60.71    42.00    70.00     66.57
# Zurab Khizanishvili            53.00       50.00    68.00    70.50     68.00
# Zvjezdan Misimovic             72.10       75.80    58.00    63.00     64.10
# de Oliveira Cleber Monteiro    69.44       62.78    69.44    70.11     72.44
# dos Santos Fabio Junior        73.25       65.50    64.00    71.00     69.50
#
#                              long_shots  aggression  interceptions  \
# player_name
# Aaron Appindangoye                34.60       65.80          52.20
# Aaron Cresswell                   54.12       65.06          57.88
# Aaron Doran                       58.04       59.12          47.27
# Aaron Galindo                     31.30       69.30          61.57
# Aaron Hughes                      24.28       69.68          76.84
# ...                                 ...         ...            ...
# Zsolt Low                         56.71       71.00          68.29
# Zurab Khizanishvili               46.00       71.00          72.25
# Zvjezdan Misimovic                79.00       57.50          49.20
# de Oliveira Cleber Monteiro       64.11       60.11          64.11
# dos Santos Fabio Junior           63.25       74.75          44.50
#
#                              positioning  vision  penalties  marking  \
# player_name
# Aaron Appindangoye                 44.60   53.60      47.60    63.80
# Aaron Cresswell                    51.48   57.45      53.12    69.39
# Aaron Doran                        61.81   69.38      60.54    22.04
# Aaron Galindo                      35.91   53.78      41.74    70.61
# Aaron Hughes                       40.08   46.48      52.96    77.60
# ...                                  ...     ...        ...      ...
# Zsolt Low                          61.57   66.00      61.00    61.00
# Zurab Khizanishvili                56.50   63.00      64.00    70.75
# Zvjezdan Misimovic                 76.20   87.10      70.90    26.20
# de Oliveira Cleber Monteiro        62.00   66.22      53.11    62.78
# dos Santos Fabio Junior            73.00   66.00      72.50    34.00
#
#                              standing_tackle  sliding_tackle  gk_diving  \
# player_name
# Aaron Appindangoye                     66.00           67.80       5.60
# Aaron Cresswell                        68.79           71.52      12.18
# Aaron Doran                            21.12           21.35      14.04
# Aaron Galindo                          70.65           68.04      14.17
# Aaron Hughes                           76.04           74.60       8.28
# ...                                      ...             ...        ...
# Zsolt Low                              64.29           59.00       7.14
# Zurab Khizanishvili                    73.25           65.00      14.00
# Zvjezdan Misimovic                     31.20           30.00       9.00
# de Oliveira Cleber Monteiro            65.33           66.67      11.11
# dos Santos Fabio Junior                26.00           18.00       9.00
#
#                              gk_handling  gk_kicking  gk_positioning  \
# player_name
# Aaron Appindangoye                 10.60        9.60            7.60
# Aaron Cresswell                     8.67       14.24           10.36
# Aaron Doran                        11.81       17.73           10.12
# Aaron Galindo                      11.17       22.87           11.17
# Aaron Hughes                        8.32       24.92           12.84
# ...                                  ...         ...             ...
# Zsolt Low                          18.71       42.43           16.71
# Zurab Khizanishvili                18.50       41.62           19.00
# Zvjezdan Misimovic                 15.40       42.10           16.20
# de Oliveira Cleber Monteiro        17.00       38.44           15.22
# dos Santos Fabio Junior            17.00       30.50           14.50
#
#                              gk_reflexes  mean_rating
# player_name
# Aaron Appindangoye                  7.60        49.10
# Aaron Cresswell                    12.91        56.23
# Aaron Doran                        13.50        53.71
# Aaron Galindo                      10.17        50.66
# Aaron Hughes                       11.92        51.45
# ...                                  ...          ...
# Zsolt Low                          16.71        56.88
# Zurab Khizanishvili                20.00        54.40
# Zvjezdan Misimovic                 12.00        61.62
# de Oliveira Cleber Monteiro        16.56        55.23
# dos Santos Fabio Junior            16.50        55.91
#
# [10848 rows x 39 columns]

# %% [markdown]
# [Terug naar het begin](#begin)

# %% [markdown]
# ## Eigen functies: Speler ratings <a name='ratingspeler'></a>

# %% [markdown]
# Voordat er wordt begonnen met het invullen van de speler ratings is het handig om het match DataFrame aan te passen, zodat deze overzichtelijker is en makkelijker gebruikt kan worden voor de visualisaties. Ook wordt er een kolom voor de seizoenen toegevoegd aan player_attributes.

# %%
#Aanmaken rp (rating_points) voor het gebruiken van visualisaties. De niet benodigde informatie (X, Y coördinaten en Betting stats) wordt weggehaald
rp = match.iloc[:, :-38]
rp = rp.drop(rp.columns[11:55], axis= 1)

#Er wordt een tijdelijke dictionary gemaakt om te mappen
team_name_dict = dict(zip(team['team_api_id'], team['team_long_name']))

#Gebruik van map om de kolommen aan te maken, vervolgens is .insert gebruikt om de kolommen op een goede plek te zetten
rp['home_team'] = rp['home_team_api_id'].map(team_name_dict)
rp['away_team'] = rp['away_team_api_id'].map(team_name_dict)

rp.insert(7, 'home_team', rp.pop('home_team'))
rp.insert(9, 'away_team', rp.pop('away_team'))

display(rp)
# Out:
#           id  country_id  league_id     season  stage                 date  \
# 0          1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1          2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2          3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3          4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4          5           1          1  2008/2009      1  2008-08-16 00:00:00
# ...      ...         ...        ...        ...    ...                  ...
# 25974  25975       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25975  25976       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25976  25977       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25977  25978       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25978  25979       24558      24558  2015/2016      9  2015-09-23 00:00:00
#
#        match_api_id                home_team  home_team_api_id  \
# 0            492473                 KRC Genk              9987
# 1            492474         SV Zulte-Waregem             10000
# 2            492475        KSV Cercle Brugge              9984
# 3            492476                 KAA Gent              9991
# 4            492477            FCV Dender EH              7947
# ...             ...                      ...               ...
# 25974       1992091            FC St. Gallen             10190
# 25975       1992092                 FC Vaduz              9824
# 25976       1992093  Grasshopper Club Zürich              9956
# 25977       1992094                   Lugano              7896
# 25978       1992095           BSC Young Boys             10192
#
#                away_team  away_team_api_id  home_team_goal  away_team_goal  \
# 0           Beerschot AC              9993               1               1
# 1       Sporting Lokeren              9994               0               0
# 2         RSC Anderlecht              8635               0               3
# 3              RAEC Mons              9998               5               0
# 4      Standard de Liège              9985               1               3
# ...                  ...               ...             ...             ...
# 25974            FC Thun             10191               1               0
# 25975          FC Luzern             10199               1               2
# 25976            FC Sion             10179               2               0
# 25977          FC Zürich             10243               0               0
# 25978           FC Basel              9931               4               3
#
#        home_player_1  home_player_2  home_player_3  home_player_4  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 25974        42231.0       678384.0        95220.0       638592.0
# 25975        33272.0        41621.0        25813.0       257845.0
# 25976       157856.0       274779.0       177689.0       294256.0
# 25977            NaN         8881.0       173534.0        39646.0
# 25978       274787.0       492132.0       108451.0        25815.0
#
#        home_player_5  home_player_6  home_player_7  home_player_8  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 25974       413155.0        45780.0       171229.0        67333.0
# 25975       114735.0        42237.0       113227.0       358156.0
# 25976        42258.0        39979.0       173936.0       147959.0
# 25977       282287.0       340790.0       393337.0         8893.0
# 25978        94553.0       384376.0       598355.0        36785.0
#
#        home_player_9  home_player_10  home_player_11  away_player_1  \
# 0                NaN             NaN             NaN            NaN
# 1                NaN             NaN             NaN            NaN
# 2                NaN             NaN             NaN            NaN
# 3                NaN             NaN             NaN            NaN
# 4                NaN             NaN             NaN            NaN
# ...              ...             ...             ...            ...
# 25974       119839.0        143790.0        195215.0       462944.0
# 25975        32343.0        531309.0         37257.0        42276.0
# 25976       451983.0         80564.0        289472.0        10637.0
# 25977       614454.0         93229.0        178142.0       274776.0
# 25978        45174.0        302079.0         71764.0       156175.0
#
#        away_player_2  away_player_3  away_player_4  away_player_5  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 25974       563066.0         8800.0        67304.0       158253.0
# 25975       114792.0       150007.0       178119.0        27232.0
# 25976        67349.0       202663.0        32597.0       114794.0
# 25977       121080.0       197757.0       260964.0       231614.0
# 25978        95216.0       172768.0        22834.0       458806.0
#
#        away_player_6  away_player_7  away_player_8  away_player_9  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 25974       133126.0       186524.0        93223.0       121115.0
# 25975       570830.0       260708.0       201704.0        36382.0
# 25976       188114.0        25840.0       482200.0        95230.0
# 25977       113235.0        41116.0       462608.0        42262.0
# 25978       207234.0        25772.0        40274.0        34035.0
#
#        away_player_10  away_player_11
# 0                 NaN             NaN
# 1                 NaN             NaN
# 2                 NaN             NaN
# 3                 NaN             NaN
# 4                 NaN             NaN
# ...               ...             ...
# 25974        232110.0        289732.0
# 25975         34082.0         95257.0
# 25976        451335.0        275122.0
# 25977         92252.0        194532.0
# 25978         41726.0        527103.0
#
# [25979 rows x 35 columns]

# %%
#Aanmaken van seizoen kolom voor player_attributes, voor het invullen van de ratings.
player_attributes['season'] = kolom_seizoen(player_attributes, 'date')

# %% [markdown]
# Vervolgens zullen er 3 functies worden aangemaakt die het mogelijk maken om de visualisaties gemakkelijk te maken op basis van een rating. Door deze functies is het simpel en efficiënt om meerdere ratings te bekijken.

# %% [markdown]
# ### rating_punten

# %% [markdown]
# De eerste functie zorgt ervoor dat er in totaal 24 kolommen worden toegevoegd aan het DataFrame. Van deze kolommen hebben 22 betrekking op de gegeven rating en de andere 2 kolommen zijn punten voor het Home_team of Away_team.

# %%
def rating_punten(categorie):
    """
    Voegt de gemiddelde rating van een speler voor een specifieke categorie toe aan een dataframe met voetbalwedstrijden.
    
    Parameters:
    ----------------
    categorie : str
        De categorie van de speler rating die moet worden toegevoegd aan het dataframe.

    Returns:
    -----------------
    rp_c : pandas.DataFrame 
        Een dataframe met de rating van de spelers. De toegevoegde kolommen bevatten de categorie plus 
        het kenmerk 'hp' of 'ap' voor de thuis- of uitploeg. Als de rating niet gevonden kan worden voor een speler, 
        wordt er NaN toegevoegd.
    """
    
    #Eerst worden er een dataframe en 2 lijsten aangemaakt voor gebruik binnen de functie
    df = player_attributes.groupby(by=['season', 'player_api_id'])[categorie].mean().reset_index().sort_values(['season', 'player_api_id'])
    
    match_players =  ['home_player_' + str(pl_num) for pl_num in range(1,12)] + \
                                ['away_player_' + str(pl_num) for pl_num in range(1,12)]
    
    match_players_rating = [categorie + '_hp' + s.replace('home_player', '') if i < 11 
                                    else categorie + '_ap' + s.replace('away_player', '') 
                                    for i, s in enumerate(match_players)]

    #Aanmaken van een dictionary om over te loopen
    rating_dict = {}
    for season in df["season"].unique():
        dftemp = df.loc[df["season"] == season]
        rating_dict[season] = dict(zip(dftemp['player_api_id'], dftemp[categorie]))
        
    #Voor elke rij in de kolommen zoekt de lc de rating op in rating_map. Als de rating niet gevonden is returned hij NaN.
    for kol_rating, kol_players in zip(match_players_rating, match_players):
        rp[kol_rating] = [rating_dict[season].get(p, np.nan) for season, p in zip(rp['season'], rp[kol_players])]
    
    #Aanmaken van kolommen met de punten die per wedstrijd zijn verkregen
    rp['home_points'] = [3 if h > a else 1 if h == a else 0 for h, a in zip(rp['home_team_goal'], rp['away_team_goal'])]
    rp['away_points'] = [3 if a > h else 1 if a == h else 0 for h, a in zip(rp['home_team_goal'], rp['away_team_goal'])]

    return rp

# %% [markdown]
# [Terug naar het begin](#begin)

# %% [markdown]
# ### df_gemiddelde

# %% [markdown]
# De functie df_gemiddelde zorgt ervoor dat voor elke positie de gemiddelde rating wordt berekent. Ook berekent de functie de gemiddelde rating van alle spelers (zowel thuis als uit) en berekent de functie het aantal wedstrijden, totaal behaalde punten en het gemiddelde aantal punten per wedstrijd. Deze berekeningen voegt de functie samen in 1 DataFrame.

# %%
def df_gemiddelde(df, categorie, seizoen = '2009/2010', league = 13274):
    """
    Maakt een dataframe met daarin statistieken over een specifiek onderwerp, per seizoen van een gegeven league.
    
    Parameters:
    ------------------
    df : pandas.DataFrame
        Het dataframe dat gemaakt is met rating_punten. Het kan ook een ander dataframe zijn, maar 
    
    categorie : str
        De categorie van de speler rating die moet worden gebruikt in het dataframe.
    
    seizoen : str
        Het seizoen waarin de data zich bevind
    
    league : int
        De league_id van de league die bekeken gaat worden
        
    Returns:
    --------------
    df_teams : pandas.DataFrame
        Een dataframe met de gemiddelde rating van alle posities, de gemiddelde rating per team, het aantal wedstrijden,
        het totaal aantal punten behaald en het gemiddeld aantal punten per wedstrijd. Het vershil tussen de ratings van het
        uit en thuis spelen is aangegeven met 'ap' of 'hp'.
    
    """
    
    #dataframe filteren op seizoen en league ID
    temp = df[(df['season'] == seizoen) & (df['league_id'] == league)]

    #lijst aanmaken voor de kolommen met de ratings
    kolommen = [categorie + '_hp_' + str(pl_num) for pl_num in range(1,12)] + \
                         [categorie + '_ap_' + str(pl_num) for pl_num in range(1,12)]

    #aanmaken van home en away df met daarin de juiste ratings
    df_home = temp.groupby('home_team')[kolommen[0 : 11]].mean().reset_index()
    df_away = temp.groupby('away_team')[kolommen[11 : 22]].mean().reset_index()

    #mergen om zowel home als away team in dezelfde dataframe te krijgen
    df_teams = pd.merge(df_home, df_away, left_on = 'home_team', right_on = 'away_team') \
                            .drop('away_team', axis = 1).rename(columns={'home_team' : 'Team'})

    #gemiddelde berekenen van alle ratings
    df_teams[f'gem_{categorie}'] = df_teams[[k for k in kolommen]].mean(axis=1)

    #berekenen van aantal wedstrijden en behaalde punten voor thuis en uit
    dph = temp.groupby('home_team')['home_points'].agg(totaal_punten='sum', wedstrijden='size').reset_index()
    dpa = temp.groupby('away_team')['away_points'].agg(totaal_punten='sum', wedstrijden='size').reset_index()
    
    #Toevoegen aantal wedstrijden, aantal punten en gem punten
    df_teams['wedstrijden'] = dph['wedstrijden'] + dpa['wedstrijden']
    df_teams['totaal_punten'] = dph['totaal_punten'] + dpa['totaal_punten']
    df_teams['gem_punten'] = df_teams['totaal_punten'] / df_teams['wedstrijden']
    
    return df_teams

# %% [markdown]
# [Terug naar het begin](#begin)

# %% [markdown]
# ### rating_grafieken

# %% [markdown]
# De laatste functie maakt 3 grafieken aan, gebaseerd op het DataFrame van df_gemiddelde en een gegeven categorie.

# %%
def rating_grafieken(df, categorie):
    """
    Deze functie draait over een aantal kolommen in een dataframe en maakt passende
    visualisaties.
    
    Parameters:
    -----------
    df : pandas.DataFrame
        Het dataframe waarin je de bewerking wilt uitvoeren.
    
    categorie : str
        De categorie kolom waarover je de bewerking wilt uitvoeren.
    
    Returns:
    --------
    None:
        In plaats van een return zorgt de functie ervoor dat er 3 grafieken worden getoond. 
    """
    
    #Grafiek van gem_categorie per Team
    plt.subplots(figsize=(15, 5))
    plt.ylim(ymin = min(df[f'gem_{categorie}'] - 5), ymax = max(df[f'gem_{categorie}'] + 1))
    sns.barplot(data= df, x= 'Team', y= f'gem_{categorie}', color = 'skyblue')
    plt.xticks(rotation = 45)
    plt.title(f'Gemiddelde {categorie} per team')
    plt.show()
    
    #Grafiek van gem_punten per Team  
    plt.subplots(figsize=(15, 5))
    sns.barplot(data= df, x= 'Team', y= 'gem_punten', color = 'skyblue')
    plt.xticks(rotation = 45)
    plt.title(f'Gemiddelde punten per team')
    plt.show()

    #Berekenen van de correlatie voor de titel van de scatterplot
    corr = round(np.corrcoef(df[f'gem_{categorie}'], df['gem_punten'])[0,1], 3)
    
    #Grafiek van gem_categorie t.o.v. gem_punten
    plt.subplots(figsize=(10, 5))
    sns.scatterplot(data= df, x= f'gem_{categorie}', y='gem_punten', hue= 'Team')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
    plt.title(f'Gemiddelde punten vergeleken met gemiddelde {categorie}, correlatie is: {corr}')
    plt.show()

# %% [markdown]
# [Terug naar het begin](#begin)

# %% [markdown]
# ## Onderzoeken van de ratings <a name='rating'></a>

# %% [markdown]
# Nu worden de voorheen gemaakt functies uitgevoert op 2 verschillende kolommen van player_attributes: overall_rating en reactions. Deze waarden zullen gebaseerd zijn op seizoen 2009/2010, aangezien dat de standaard waarde voor seizoen is bij de functie df_gemiddelde.

# %%
#De DataFrames voor overall_rating
rp_or = rating_punten('overall_rating')
rp_or_gem = df_gemiddelde(rp_or, 'overall_rating')
display(rp_or, rp_or_gem)
# Out:
#           id  country_id  league_id     season  stage                 date  \
# 0          1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1          2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2          3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3          4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4          5           1          1  2008/2009      1  2008-08-16 00:00:00
# ...      ...         ...        ...        ...    ...                  ...
# 25974  25975       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25975  25976       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25976  25977       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25977  25978       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25978  25979       24558      24558  2015/2016      9  2015-09-23 00:00:00
#
#        match_api_id                home_team  home_team_api_id  \
# 0            492473                 KRC Genk              9987
# 1            492474         SV Zulte-Waregem             10000
# 2            492475        KSV Cercle Brugge              9984
# 3            492476                 KAA Gent              9991
# 4            492477            FCV Dender EH              7947
# ...             ...                      ...               ...
# 25974       1992091            FC St. Gallen             10190
# 25975       1992092                 FC Vaduz              9824
# 25976       1992093  Grasshopper Club Zürich              9956
# 25977       1992094                   Lugano              7896
# 25978       1992095           BSC Young Boys             10192
#
#                away_team  away_team_api_id  home_team_goal  away_team_goal  \
# 0           Beerschot AC              9993               1               1
# 1       Sporting Lokeren              9994               0               0
# 2         RSC Anderlecht              8635               0               3
# 3              RAEC Mons              9998               5               0
# 4      Standard de Liège              9985               1               3
# ...                  ...               ...             ...             ...
# 25974            FC Thun             10191               1               0
# 25975          FC Luzern             10199               1               2
# 25976            FC Sion             10179               2               0
# 25977          FC Zürich             10243               0               0
# 25978           FC Basel              9931               4               3
#
#        home_player_1  home_player_2  home_player_3  home_player_4  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 25974        42231.0       678384.0        95220.0       638592.0
# 25975        33272.0        41621.0        25813.0       257845.0
# 25976       157856.0       274779.0       177689.0       294256.0
# 25977            NaN         8881.0       173534.0        39646.0
# 25978       274787.0       492132.0       108451.0        25815.0
#
#        home_player_5  home_player_6  home_player_7  home_player_8  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 25974       413155.0        45780.0       171229.0        67333.0
# 25975       114735.0        42237.0       113227.0       358156.0
# 25976        42258.0        39979.0       173936.0       147959.0
# 25977       282287.0       340790.0       393337.0         8893.0
# 25978        94553.0       384376.0       598355.0        36785.0
#
#        home_player_9  home_player_10  home_player_11  away_player_1  \
# 0                NaN             NaN             NaN            NaN
# 1                NaN             NaN             NaN            NaN
# 2                NaN             NaN             NaN            NaN
# 3                NaN             NaN             NaN            NaN
# 4                NaN             NaN             NaN            NaN
# ...              ...             ...             ...            ...
# 25974       119839.0        143790.0        195215.0       462944.0
# 25975        32343.0        531309.0         37257.0        42276.0
# 25976       451983.0         80564.0        289472.0        10637.0
# 25977       614454.0         93229.0        178142.0       274776.0
# 25978        45174.0        302079.0         71764.0       156175.0
#
#        away_player_2  away_player_3  away_player_4  away_player_5  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 25974       563066.0         8800.0        67304.0       158253.0
# 25975       114792.0       150007.0       178119.0        27232.0
# 25976        67349.0       202663.0        32597.0       114794.0
# 25977       121080.0       197757.0       260964.0       231614.0
# 25978        95216.0       172768.0        22834.0       458806.0
#
#        away_player_6  away_player_7  away_player_8  away_player_9  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 25974       133126.0       186524.0        93223.0       121115.0
# 25975       570830.0       260708.0       201704.0        36382.0
# 25976       188114.0        25840.0       482200.0        95230.0
# 25977       113235.0        41116.0       462608.0        42262.0
# 25978       207234.0        25772.0        40274.0        34035.0
#
#        away_player_10  away_player_11  overall_rating_hp_1  \
# 0                 NaN             NaN                  NaN
# 1                 NaN             NaN                  NaN
# 2                 NaN             NaN                  NaN
# 3                 NaN             NaN                  NaN
# 4                 NaN             NaN                  NaN
# ...               ...             ...                  ...
# 25974        232110.0        289732.0            62.500000
# 25975         34082.0         95257.0            62.000000
# 25976        451335.0        275122.0            64.000000
# 25977         92252.0        194532.0                  NaN
# 25978         41726.0        527103.0            71.333333
#
#        overall_rating_hp_2  overall_rating_hp_3  overall_rating_hp_4  \
# 0                      NaN                  NaN                  NaN
# 1                      NaN                  NaN                  NaN
# 2                      NaN                  NaN                  NaN
# 3                      NaN                  NaN                  NaN
# 4                      NaN                  NaN                  NaN
# ...                    ...                  ...                  ...
# 25974                52.75            63.000000            60.000000
# 25975                57.00            62.000000            58.000000
# 25976                59.80            62.857143            68.833333
# 25977                64.00            66.000000            53.000000
# 25978                67.50            71.000000            72.500000
#
#        overall_rating_hp_5  overall_rating_hp_6  overall_rating_hp_7  \
# 0                      NaN                  NaN                  NaN
# 1                      NaN                  NaN                  NaN
# 2                      NaN                  NaN                  NaN
# 3                      NaN                  NaN                  NaN
# 4                      NaN                  NaN                  NaN
# ...                    ...                  ...                  ...
# 25974                 65.0            59.000000            65.000000
# 25975                 58.5            62.000000            65.500000
# 25976                 62.0            75.000000            66.800000
# 25977                 61.0            60.333333            59.333333
# 25978                 66.5            71.333333            59.800000
#
#        overall_rating_hp_8  overall_rating_hp_9  overall_rating_hp_10  \
# 0                      NaN                  NaN                   NaN
# 1                      NaN                  NaN                   NaN
# 2                      NaN                  NaN                   NaN
# 3                      NaN                  NaN                   NaN
# 4                      NaN                  NaN                   NaN
# ...                    ...                  ...                   ...
# 25974                62.00            65.714286                  66.6
# 25975                60.00            66.250000                  53.4
# 25976                72.00            68.000000                  74.0
# 25977                63.75            61.750000                  57.5
# 25978                70.00            74.666667                  70.0
#
#        overall_rating_hp_11  overall_rating_ap_1  overall_rating_ap_2  \
# 0                       NaN                  NaN                  NaN
# 1                       NaN                  NaN                  NaN
# 2                       NaN                  NaN                  NaN
# 3                       NaN                  NaN                  NaN
# 4                       NaN                  NaN                  NaN
# ...                     ...                  ...                  ...
# 25974             59.000000            57.500000            53.333333
# 25975             57.333333            62.666667            59.750000
# 25976             73.833333            67.500000            67.000000
# 25977             61.666667            61.000000            66.000000
# 25978             72.000000            75.000000            73.200000
#
#        overall_rating_ap_3  overall_rating_ap_4  overall_rating_ap_5  \
# 0                      NaN                  NaN                  NaN
# 1                      NaN                  NaN                  NaN
# 2                      NaN                  NaN                  NaN
# 3                      NaN                  NaN                  NaN
# 4                      NaN                  NaN                  NaN
# ...                    ...                  ...                  ...
# 25974            62.000000            57.500000            65.000000
# 25975            64.000000            65.333333            68.250000
# 25976            66.000000            73.000000            65.000000
# 25977            63.000000            62.000000            57.666667
# 25978            68.428571            77.142857            68.000000
#
#        overall_rating_ap_6  overall_rating_ap_7  overall_rating_ap_8  \
# 0                      NaN                  NaN                  NaN
# 1                      NaN                  NaN                  NaN
# 2                      NaN                  NaN                  NaN
# 3                      NaN                  NaN                  NaN
# 4                      NaN                  NaN                  NaN
# ...                    ...                  ...                  ...
# 25974            63.000000                 64.8            64.666667
# 25975            52.666667                 60.4            66.666667
# 25976            63.250000                 68.0            66.666667
# 25977            63.000000                 74.0            58.000000
# 25978            70.000000                 74.8            69.666667
#
#        overall_rating_ap_9  overall_rating_ap_10  overall_rating_ap_11  \
# 0                      NaN                   NaN                   NaN
# 1                      NaN                   NaN                   NaN
# 2                      NaN                   NaN                   NaN
# 3                      NaN                   NaN                   NaN
# 4                      NaN                   NaN                   NaN
# ...                    ...                   ...                   ...
# 25974            64.833333             60.333333             67.000000
# 25975            66.333333             68.000000             70.000000
# 25976            68.666667             66.600000             72.666667
# 25977            72.500000             67.400000             68.000000
# 25978            75.333333             74.000000             76.000000
#
#        home_points  away_points
# 0                1            1
# 1                1            1
# 2                0            3
# 3                3            0
# 4                0            3
# ...            ...          ...
# 25974            3            0
# 25975            0            3
# 25976            3            0
# 25977            1            1
# 25978            3            0
#
# [25979 rows x 59 columns]
#                 Team  overall_rating_hp_1  overall_rating_hp_2  \
# 0       ADO Den Haag            63.117647            64.264706
# 1                 AZ            75.705882            71.441176
# 2               Ajax            76.352941            74.500000
# 3       FC Groningen            70.911765            66.735294
# 4          FC Twente            74.000000            72.500000
# 5         FC Utrecht            75.500000            66.823529
# 6          Feyenoord            67.676471            65.823529
# 7    Heracles Almelo            69.176471            64.500000
# 8             N.E.C.            75.000000            63.941176
# 9          NAC Breda            71.000000            66.500000
# 10               PSV            76.500000            72.617647
# 11      RKC Waalwijk            62.588235            64.117647
# 12  Roda JC Kerkrade            64.323529            65.470588
# 13     SC Heerenveen            68.461538            68.058824
# 14  Sparta Rotterdam            66.000000            64.088235
# 15         VVV-Venlo            66.000000            62.558824
# 16           Vitesse            74.500000            66.588235
# 17         Willem II            68.441176            64.117647
#
#     overall_rating_hp_3  overall_rating_hp_4  overall_rating_hp_5  \
# 0             66.411765            65.794118            63.235294
# 1             72.500000            72.029412            70.411765
# 2             72.558824            75.794118            70.941176
# 3             69.852941            74.000000            70.500000
# 4             74.529412            76.235294            69.647059
# 5             68.176471            68.323529            66.676471
# 6             73.529412            71.852941            73.176471
# 7             68.968750            68.558824            65.000000
# 8             65.470588            69.147059            64.500000
# 9             71.470588            72.882353            69.205882
# 10            74.470588            74.882353            70.823529
# 11            64.205882            63.235294            64.352941
# 12            66.617647            68.352941            65.029412
# 13            68.558824            68.970588            68.323529
# 14            64.470588            64.529412            63.000000
# 15            63.294118            69.588235            64.647059
# 16            66.882353            63.176471            65.705882
# 17            65.264706            64.970588            64.500000
#
#     overall_rating_hp_6  overall_rating_hp_7  overall_rating_hp_8  \
# 0             66.088235            66.352941            63.617647
# 1             71.235294            73.529412            74.558824
# 2             74.588235            72.941176            72.058824
# 3             70.352941            70.205882            70.617647
# 4             73.647059            75.088235            74.941176
# 5             69.852941            70.588235            67.911765
# 6             70.588235            71.382353            72.558824
# 7             68.000000            67.911765            66.264706
# 8             66.882353            65.500000            67.058824
# 9             68.264706            67.235294            70.264706
# 10            78.500000            76.205882            76.411765
# 11            63.147059            64.500000            63.176471
# 12            65.029412            64.923077            66.647059
# 13            71.647059            69.676471            71.323529
# 14            65.352941            64.062500            67.500000
# 15            63.500000            71.500000            63.764706
# 16            68.411765            69.029412            65.911765
# 17            65.382353            67.882353            66.843750
#
#     overall_rating_hp_9  overall_rating_hp_10  overall_rating_hp_11  \
# 0             64.176471             64.923077             64.937500
# 1             75.000000             77.029412             76.529412
# 2             75.058824             79.882353             76.588235
# 3             69.352941             68.352941             67.911765
# 4             76.676471             73.235294             76.323529
# 5             68.470588             68.617647             68.235294
# 6             70.323529             72.617647             71.558824
# 7             66.058824             68.000000             66.941176
# 8             65.235294             68.000000             65.911765
# 9             70.588235             72.558824             70.000000
# 10            75.531250             73.970588             78.264706
# 11            65.558824             64.176471             66.705882
# 12            66.941176             67.558824             67.058824
# 13            73.882353             69.941176             68.235294
# 14            67.000000             67.176471             64.617647
# 15            67.411765             65.352941             65.941176
# 16            67.529412             67.500000             68.852941
# 17            65.323529             66.911765             66.794118
#
#     overall_rating_ap_1  overall_rating_ap_2  overall_rating_ap_3  \
# 0             63.000000            64.764706            66.676471
# 1             76.029412            72.588235            72.500000
# 2             76.500000            74.500000            72.558824
# 3             70.470588            66.823529            71.000000
# 4             74.000000            72.764706            74.647059
# 5             75.000000            67.117647            68.500000
# 6             67.882353            66.117647            73.529412
# 7             70.000000            64.500000            69.031250
# 8             75.000000            64.176471            65.676471
# 9             71.000000            67.147059            70.029412
# 10            76.500000            72.647059            74.764706
# 11            62.588235            64.441176            64.647059
# 12            64.323529            65.264706            66.323529
# 13            68.333333            67.735294            68.323529
# 14            66.000000            63.529412            64.312500
# 15            65.875000            62.558824            63.176471
# 16            73.705882            67.941176            67.441176
# 17            68.970588            63.970588            64.058824
#
#     overall_rating_ap_4  overall_rating_ap_5  overall_rating_ap_6  \
# 0             65.352941            63.205882            65.882353
# 1             72.029412            69.970588            71.441176
# 2             74.970588            71.882353            73.647059
# 3             74.558824            69.875000            70.588235
# 4             75.588235            69.647059            73.794118
# 5             68.529412            66.558824            69.500000
# 6             71.705882            72.764706            70.705882
# 7             68.500000            64.764706            68.000000
# 8             68.323529            66.411765            67.176471
# 9             72.058824            70.176471            67.823529
# 10            74.705882            70.500000            76.970588
# 11            63.088235            64.000000            62.852941
# 12            68.470588            64.705882            65.176471
# 13            69.088235            68.470588            69.764706
# 14            64.411765            63.058824            65.937500
# 15            69.147059            64.294118            63.000000
# 16            64.000000            65.588235            68.588235
# 17            65.705882            64.333333            64.588235
#
#     overall_rating_ap_7  overall_rating_ap_8  overall_rating_ap_9  \
# 0             66.656250            63.029412            64.058824
# 1             73.352941            75.441176            75.441176
# 2             73.323529            73.500000            75.294118
# 3             69.705882            69.911765            69.441176
# 4             74.941176            73.117647            78.588235
# 5             70.882353            67.470588            68.441176
# 6             71.970588            72.323529            70.294118
# 7             67.911765            66.218750            66.000000
# 8             66.411765            67.000000            65.735294
# 9             67.088235            70.882353            70.352941
# 10            76.470588            75.500000            75.531250
# 11            64.382353            63.264706            65.264706
# 12            65.409091            66.852941            67.000000
# 13            70.352941            72.647059            73.411765
# 14            63.970588            67.058824            67.500000
# 15            73.352941            62.882353            67.264706
# 16            68.264706            66.117647            67.617647
# 17            67.441176            66.735294            64.823529
#
#     overall_rating_ap_10  overall_rating_ap_11  gem_overall_rating  \
# 0              65.733333             65.235294           64.841585
# 1              77.235294             77.000000           73.772727
# 2              79.352941             76.470588           74.693850
# 3              67.470588             68.323529           69.861965
# 4              73.470588             74.911765           74.195187
# 5              69.029412             69.058824           69.057487
# 6              72.441176             70.911765           70.987968
# 7              68.000000             67.000000           67.241227
# 8              67.647059             66.647059           67.129679
# 9              71.470588             70.294118           69.922460
# 10             74.529412             78.264706           75.207386
# 11             64.764706             66.382353           64.156417
# 12             66.794118             67.343750           66.164413
# 13             70.117647             68.500000           69.719286
# 14             66.852941             65.558824           65.272226
# 15             65.470588             66.294118           65.767045
# 16             67.352941             68.558824           67.693850
# 17             67.147059             66.852941           65.957247
#
#     wedstrijden  totaal_punten  gem_punten
# 0            34             30    0.882353
# 1            34             62    1.823529
# 2            34             85    2.500000
# 3            34             49    1.441176
# 4            34             86    2.529412
# 5            34             53    1.558824
# 6            34             63    1.852941
# 7            34             56    1.647059
# 8            34             33    0.970588
# 9            34             46    1.352941
# 10           34             78    2.294118
# 11           34             15    0.441176
# 12           34             47    1.382353
# 13           34             37    1.088235
# 14           34             26    0.764706
# 15           34             35    1.029412
# 16           34             32    0.941176
# 17           34             23    0.676471

# %%
#De grafieken van overall_rating
rating_grafieken(rp_or_gem, 'overall_rating')

# %%
#De DataFrames voor reactions
rp_r = rating_punten('reactions')
rp_r_gem = df_gemiddelde(rp_r, 'reactions')
display(rp_r, rp_r_gem)
# Out:
#           id  country_id  league_id     season  stage                 date  \
# 0          1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1          2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2          3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3          4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4          5           1          1  2008/2009      1  2008-08-16 00:00:00
# ...      ...         ...        ...        ...    ...                  ...
# 25974  25975       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25975  25976       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25976  25977       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25977  25978       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25978  25979       24558      24558  2015/2016      9  2015-09-23 00:00:00
#
#        match_api_id                home_team  home_team_api_id  \
# 0            492473                 KRC Genk              9987
# 1            492474         SV Zulte-Waregem             10000
# 2            492475        KSV Cercle Brugge              9984
# 3            492476                 KAA Gent              9991
# 4            492477            FCV Dender EH              7947
# ...             ...                      ...               ...
# 25974       1992091            FC St. Gallen             10190
# 25975       1992092                 FC Vaduz              9824
# 25976       1992093  Grasshopper Club Zürich              9956
# 25977       1992094                   Lugano              7896
# 25978       1992095           BSC Young Boys             10192
#
#                away_team  away_team_api_id  home_team_goal  away_team_goal  \
# 0           Beerschot AC              9993               1               1
# 1       Sporting Lokeren              9994               0               0
# 2         RSC Anderlecht              8635               0               3
# 3              RAEC Mons              9998               5               0
# 4      Standard de Liège              9985               1               3
# ...                  ...               ...             ...             ...
# 25974            FC Thun             10191               1               0
# 25975          FC Luzern             10199               1               2
# 25976            FC Sion             10179               2               0
# 25977          FC Zürich             10243               0               0
# 25978           FC Basel              9931               4               3
#
#        home_player_1  home_player_2  home_player_3  home_player_4  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 25974        42231.0       678384.0        95220.0       638592.0
# 25975        33272.0        41621.0        25813.0       257845.0
# 25976       157856.0       274779.0       177689.0       294256.0
# 25977            NaN         8881.0       173534.0        39646.0
# 25978       274787.0       492132.0       108451.0        25815.0
#
#        home_player_5  home_player_6  home_player_7  home_player_8  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 25974       413155.0        45780.0       171229.0        67333.0
# 25975       114735.0        42237.0       113227.0       358156.0
# 25976        42258.0        39979.0       173936.0       147959.0
# 25977       282287.0       340790.0       393337.0         8893.0
# 25978        94553.0       384376.0       598355.0        36785.0
#
#        home_player_9  home_player_10  home_player_11  away_player_1  \
# 0                NaN             NaN             NaN            NaN
# 1                NaN             NaN             NaN            NaN
# 2                NaN             NaN             NaN            NaN
# 3                NaN             NaN             NaN            NaN
# 4                NaN             NaN             NaN            NaN
# ...              ...             ...             ...            ...
# 25974       119839.0        143790.0        195215.0       462944.0
# 25975        32343.0        531309.0         37257.0        42276.0
# 25976       451983.0         80564.0        289472.0        10637.0
# 25977       614454.0         93229.0        178142.0       274776.0
# 25978        45174.0        302079.0         71764.0       156175.0
#
#        away_player_2  away_player_3  away_player_4  away_player_5  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 25974       563066.0         8800.0        67304.0       158253.0
# 25975       114792.0       150007.0       178119.0        27232.0
# 25976        67349.0       202663.0        32597.0       114794.0
# 25977       121080.0       197757.0       260964.0       231614.0
# 25978        95216.0       172768.0        22834.0       458806.0
#
#        away_player_6  away_player_7  away_player_8  away_player_9  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 25974       133126.0       186524.0        93223.0       121115.0
# 25975       570830.0       260708.0       201704.0        36382.0
# 25976       188114.0        25840.0       482200.0        95230.0
# 25977       113235.0        41116.0       462608.0        42262.0
# 25978       207234.0        25772.0        40274.0        34035.0
#
#        away_player_10  away_player_11  overall_rating_hp_1  \
# 0                 NaN             NaN                  NaN
# 1                 NaN             NaN                  NaN
# 2                 NaN             NaN                  NaN
# 3                 NaN             NaN                  NaN
# 4                 NaN             NaN                  NaN
# ...               ...             ...                  ...
# 25974        232110.0        289732.0            62.500000
# 25975         34082.0         95257.0            62.000000
# 25976        451335.0        275122.0            64.000000
# 25977         92252.0        194532.0                  NaN
# 25978         41726.0        527103.0            71.333333
#
#        overall_rating_hp_2  overall_rating_hp_3  overall_rating_hp_4  \
# 0                      NaN                  NaN                  NaN
# 1                      NaN                  NaN                  NaN
# 2                      NaN                  NaN                  NaN
# 3                      NaN                  NaN                  NaN
# 4                      NaN                  NaN                  NaN
# ...                    ...                  ...                  ...
# 25974                52.75            63.000000            60.000000
# 25975                57.00            62.000000            58.000000
# 25976                59.80            62.857143            68.833333
# 25977                64.00            66.000000            53.000000
# 25978                67.50            71.000000            72.500000
#
#        overall_rating_hp_5  overall_rating_hp_6  overall_rating_hp_7  \
# 0                      NaN                  NaN                  NaN
# 1                      NaN                  NaN                  NaN
# 2                      NaN                  NaN                  NaN
# 3                      NaN                  NaN                  NaN
# 4                      NaN                  NaN                  NaN
# ...                    ...                  ...                  ...
# 25974                 65.0            59.000000            65.000000
# 25975                 58.5            62.000000            65.500000
# 25976                 62.0            75.000000            66.800000
# 25977                 61.0            60.333333            59.333333
# 25978                 66.5            71.333333            59.800000
#
#        overall_rating_hp_8  overall_rating_hp_9  overall_rating_hp_10  \
# 0                      NaN                  NaN                   NaN
# 1                      NaN                  NaN                   NaN
# 2                      NaN                  NaN                   NaN
# 3                      NaN                  NaN                   NaN
# 4                      NaN                  NaN                   NaN
# ...                    ...                  ...                   ...
# 25974                62.00            65.714286                  66.6
# 25975                60.00            66.250000                  53.4
# 25976                72.00            68.000000                  74.0
# 25977                63.75            61.750000                  57.5
# 25978                70.00            74.666667                  70.0
#
#        overall_rating_hp_11  overall_rating_ap_1  overall_rating_ap_2  \
# 0                       NaN                  NaN                  NaN
# 1                       NaN                  NaN                  NaN
# 2                       NaN                  NaN                  NaN
# 3                       NaN                  NaN                  NaN
# 4                       NaN                  NaN                  NaN
# ...                     ...                  ...                  ...
# 25974             59.000000            57.500000            53.333333
# 25975             57.333333            62.666667            59.750000
# 25976             73.833333            67.500000            67.000000
# 25977             61.666667            61.000000            66.000000
# 25978             72.000000            75.000000            73.200000
#
#        overall_rating_ap_3  overall_rating_ap_4  overall_rating_ap_5  \
# 0                      NaN                  NaN                  NaN
# 1                      NaN                  NaN                  NaN
# 2                      NaN                  NaN                  NaN
# 3                      NaN                  NaN                  NaN
# 4                      NaN                  NaN                  NaN
# ...                    ...                  ...                  ...
# 25974            62.000000            57.500000            65.000000
# 25975            64.000000            65.333333            68.250000
# 25976            66.000000            73.000000            65.000000
# 25977            63.000000            62.000000            57.666667
# 25978            68.428571            77.142857            68.000000
#
#        overall_rating_ap_6  overall_rating_ap_7  overall_rating_ap_8  \
# 0                      NaN                  NaN                  NaN
# 1                      NaN                  NaN                  NaN
# 2                      NaN                  NaN                  NaN
# 3                      NaN                  NaN                  NaN
# 4                      NaN                  NaN                  NaN
# ...                    ...                  ...                  ...
# 25974            63.000000                 64.8            64.666667
# 25975            52.666667                 60.4            66.666667
# 25976            63.250000                 68.0            66.666667
# 25977            63.000000                 74.0            58.000000
# 25978            70.000000                 74.8            69.666667
#
#        overall_rating_ap_9  overall_rating_ap_10  overall_rating_ap_11  \
# 0                      NaN                   NaN                   NaN
# 1                      NaN                   NaN                   NaN
# 2                      NaN                   NaN                   NaN
# 3                      NaN                   NaN                   NaN
# 4                      NaN                   NaN                   NaN
# ...                    ...                   ...                   ...
# 25974            64.833333             60.333333             67.000000
# 25975            66.333333             68.000000             70.000000
# 25976            68.666667             66.600000             72.666667
# 25977            72.500000             67.400000             68.000000
# 25978            75.333333             74.000000             76.000000
#
#        home_points  away_points  reactions_hp_1  reactions_hp_2  \
# 0                1            1             NaN             NaN
# 1                1            1             NaN             NaN
# 2                0            3             NaN             NaN
# 3                3            0             NaN             NaN
# 4                0            3             NaN             NaN
# ...            ...          ...             ...             ...
# 25974            3            0            63.5            56.0
# 25975            0            3            56.0            65.0
# 25976            3            0            60.0            45.2
# 25977            1            1             NaN            67.0
# 25978            3            0            63.0            59.5
#
#        reactions_hp_3  reactions_hp_4  reactions_hp_5  reactions_hp_6  \
# 0                 NaN             NaN             NaN             NaN
# 1                 NaN             NaN             NaN             NaN
# 2                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 4                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 25974            64.0       68.000000            59.0       49.000000
# 25975            56.0       61.000000            53.0       57.000000
# 25976            64.0       67.833333            58.0       70.000000
# 25977            61.0       65.000000            58.0       63.000000
# 25978            58.0       69.000000            61.0       61.666667
#
#        reactions_hp_7  reactions_hp_8  reactions_hp_9  reactions_hp_10  \
# 0                 NaN             NaN             NaN              NaN
# 1                 NaN             NaN             NaN              NaN
# 2                 NaN             NaN             NaN              NaN
# 3                 NaN             NaN             NaN              NaN
# 4                 NaN             NaN             NaN              NaN
# ...               ...             ...             ...              ...
# 25974            62.0            65.0       55.428571             60.8
# 25975            70.0            50.0       63.000000             48.0
# 25976            68.6            76.0       64.000000             71.0
# 25977            51.0            55.0       54.000000             63.0
# 25978            57.6            68.0       72.000000             66.0
#
#        reactions_hp_11  reactions_ap_1  reactions_ap_2  reactions_ap_3  \
# 0                  NaN             NaN             NaN             NaN
# 1                  NaN             NaN             NaN             NaN
# 2                  NaN             NaN             NaN             NaN
# 3                  NaN             NaN             NaN             NaN
# 4                  NaN             NaN             NaN             NaN
# ...                ...             ...             ...             ...
# 25974        57.000000       53.500000            49.0            52.0
# 25975        63.000000       59.666667            59.5            58.0
# 25976        58.666667       63.000000            58.0            63.0
# 25977        61.000000       50.000000            58.0            53.0
# 25978        72.000000       63.000000            59.0            62.0
#
#        reactions_ap_4  reactions_ap_5  reactions_ap_6  reactions_ap_7  \
# 0                 NaN             NaN             NaN             NaN
# 1                 NaN             NaN             NaN             NaN
# 2                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 4                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 25974       57.000000            60.0       66.000000            62.0
# 25975       55.000000            66.0       54.833333            66.0
# 25976       68.000000            69.0       69.000000            70.0
# 25977       55.000000            50.0       64.000000            75.0
# 25978       70.285714            64.0       64.000000            68.8
#
#        reactions_ap_8  reactions_ap_9  reactions_ap_10  reactions_ap_11
# 0                 NaN             NaN              NaN              NaN
# 1                 NaN             NaN              NaN              NaN
# 2                 NaN             NaN              NaN              NaN
# 3                 NaN             NaN              NaN              NaN
# 4                 NaN             NaN              NaN              NaN
# ...               ...             ...              ...              ...
# 25974            58.0           69.00             64.0             71.0
# 25975            69.0           65.00             66.0             65.0
# 25976            65.0           63.00             58.0             78.0
# 25977            37.5           67.25             64.0             68.0
# 25978            71.0           65.00             76.0             73.0
#
# [25979 rows x 81 columns]
#                 Team  reactions_hp_1  reactions_hp_2  reactions_hp_3  \
# 0       ADO Den Haag       44.058824       62.764706       63.588235
# 1                 AZ       74.882353       76.000000       76.411765
# 2               Ajax       74.705882       76.000000       70.117647
# 3       FC Groningen       71.352941       68.705882       67.823529
# 4          FC Twente       77.000000       79.000000       73.647059
# 5         FC Utrecht       72.000000       68.352941       65.588235
# 6          Feyenoord       58.941176       65.411765       75.588235
# 7    Heracles Almelo       74.588235       67.000000       69.437500
# 8             N.E.C.       78.000000       63.000000       65.529412
# 9          NAC Breda       69.000000       64.705882       67.941176
# 10               PSV       71.000000       72.294118       72.352941
# 11      RKC Waalwijk       40.235294       65.058824       64.411765
# 12  Roda JC Kerkrade       55.176471       66.352941       67.470588
# 13     SC Heerenveen       60.230769       69.941176       67.647059
# 14  Sparta Rotterdam       51.000000       67.235294       64.000000
# 15         VVV-Venlo       65.933333       66.176471       65.411765
# 16           Vitesse       73.000000       65.294118       65.411765
# 17         Willem II       64.352941       59.529412       59.294118
#
#     reactions_hp_4  reactions_hp_5  reactions_hp_6  reactions_hp_7  \
# 0        65.470588       61.529412       66.941176       66.823529
# 1        73.176471       73.352941       72.588235       75.941176
# 2        72.823529       72.294118       74.794118       74.558824
# 3        74.941176       65.000000       70.823529       68.000000
# 4        72.470588       71.411765       74.529412       72.500000
# 5        67.882353       66.235294       70.147059       69.352941
# 6        73.352941       74.588235       70.911765       72.852941
# 7        67.205882       61.000000       72.235294       73.235294
# 8        68.088235       66.970588       65.294118       68.058824
# 9        68.117647       72.882353       71.529412       71.000000
# 10       73.176471       73.882353       77.352941       77.205882
# 11       65.647059       63.705882       64.588235       67.117647
# 12       65.764706       67.470588       67.411765       66.884615
# 13       66.823529       68.000000       73.235294       71.058824
# 14       67.941176       65.000000       66.705882       66.875000
# 15       64.941176       67.941176       65.625000       71.794118
# 16       59.000000       63.117647       68.117647       68.000000
# 17       62.529412       62.791667       69.235294       62.941176
#
#     reactions_hp_8  reactions_hp_9  reactions_hp_10  reactions_hp_11  \
# 0        67.029412       62.735294        66.461538        65.781250
# 1        74.352941       76.617647        79.941176        78.235294
# 2        71.735294       74.617647        84.117647        78.058824
# 3        70.470588       72.705882        70.764706        70.705882
# 4        72.176471       77.647059        76.323529        77.970588
# 5        68.852941       69.500000        71.235294        72.705882
# 6        70.764706       74.294118        76.411765        71.764706
# 7        65.470588       66.941176        69.000000        73.941176
# 8        65.235294       67.294118        72.000000        69.882353
# 9        71.294118       68.764706        79.705882        73.176471
# 10       72.235294       74.906250        73.529412        70.058824
# 11       63.294118       70.882353        69.705882        69.294118
# 12       69.647059       70.000000        67.382353        72.235294
# 13       71.058824       73.941176        74.000000        72.676471
# 14       72.352941       61.647059        74.176471        67.823529
# 15       63.205882       72.382353        67.529412        69.323529
# 16       64.735294       64.352941        67.468750        69.735294
# 17       64.906250       68.647059        70.941176        68.764706
#
#     reactions_ap_1  reactions_ap_2  reactions_ap_3  reactions_ap_4  \
# 0        42.294118       63.529412       65.411765       62.588235
# 1        75.411765       76.470588       76.352941       73.352941
# 2        75.000000       76.000000       70.352941       72.411765
# 3        71.117647       69.058824       68.411765       75.294118
# 4        77.000000       78.588235       73.529412       72.823529
# 5        71.000000       67.823529       65.529412       67.470588
# 6        59.294118       65.029412       75.588235       72.705882
# 7        76.000000       67.000000       69.656250       67.000000
# 8        78.000000       63.352941       63.882353       67.588235
# 9        69.000000       64.529412       66.294118       68.058824
# 10       71.000000       72.176471       73.352941       73.176471
# 11       40.235294       65.470588       64.176471       65.823529
# 12       55.176471       65.529412       66.529412       66.647059
# 13       57.666667       69.000000       67.823529       66.411765
# 14       51.000000       66.352941       63.687500       68.058824
# 15       65.312500       66.823529       64.529412       64.705882
# 16       72.647059       66.235294       66.058824       56.647059
# 17       69.176471       58.882353       57.764706       65.764706
#
#     reactions_ap_5  reactions_ap_6  reactions_ap_7  reactions_ap_8  \
# 0        61.529412       66.617647       67.093750       65.941176
# 1        73.352941       73.176471       75.088235       75.411765
# 2        72.000000       73.970588       74.911765       74.411765
# 3        65.687500       72.176471       66.529412       69.823529
# 4        71.294118       74.352941       72.176471       72.117647
# 5        66.411765       70.294118       69.735294       68.235294
# 6        74.088235       70.882353       73.264706       70.794118
# 7        61.294118       72.500000       73.117647       65.500000
# 8        67.323529       65.411765       68.176471       65.294118
# 9        73.235294       72.705882       70.470588       71.294118
# 10       73.764706       75.470588       76.970588       71.911765
# 11       63.588235       65.529412       66.705882       63.764706
# 12       66.117647       67.411765       67.272727       68.352941
# 13       68.117647       69.000000       71.647059       73.411765
# 14       65.235294       67.375000       66.941176       72.235294
# 15       67.117647       63.823529       73.558824       62.647059
# 16       63.705882       68.294118       66.705882       64.823529
# 17       62.000000       69.088235       61.764706       63.117647
#
#     reactions_ap_9  reactions_ap_10  reactions_ap_11  gem_reactions  \
# 0        62.029412        67.266667        66.176471      62.893729
# 1        77.617647        79.235294        76.852941      75.628342
# 2        75.147059        83.294118        76.852941      74.917112
# 3        72.941176        68.705882        72.000000      70.138202
# 4        79.264706        76.588235        76.617647      74.955882
# 5        69.411765        73.205882        72.294118      69.239305
# 6        73.882353        75.911765        71.764706      71.276738
# 7        66.470588        69.000000        74.000000      69.163352
# 8        67.970588        71.382353        69.264706      68.045455
# 9        68.470588        78.000000        72.823529      70.590909
# 10       74.906250        74.117647        70.441176      73.421959
# 11       69.882353        69.529412        68.235294      63.949198
# 12       70.735294        68.088235        71.625000      66.785561
# 13       74.470588        74.058824        74.900000      69.778226
# 14       63.750000        71.058824        67.470588      65.814672
# 15       73.235294        67.529412        69.647059      67.236107
# 16       65.882353        67.441176        69.323529      66.181735
# 17       68.205882        71.294118        70.000000      65.045092
#
#     wedstrijden  totaal_punten  gem_punten
# 0            34             30    0.882353
# 1            34             62    1.823529
# 2            34             85    2.500000
# 3            34             49    1.441176
# 4            34             86    2.529412
# 5            34             53    1.558824
# 6            34             63    1.852941
# 7            34             56    1.647059
# 8            34             33    0.970588
# 9            34             46    1.352941
# 10           34             78    2.294118
# 11           34             15    0.441176
# 12           34             47    1.382353
# 13           34             37    1.088235
# 14           34             26    0.764706
# 15           34             35    1.029412
# 16           34             32    0.941176
# 17           34             23    0.676471

# %%
#De grafieken van reactions
rating_grafieken(rp_r_gem, 'reactions')

# %% [markdown]
# Bij overall rating is er een duidelijke beweging te zien van links onder naar rechts boven. Hetzelfde geldt voor de reactions kolom. De observatie wordt verder bevestigd door de hoge correlaties tussen de kolommen. Deze ratings hebben dus een redelijk sterke invloed op het aantal punten dat een team heeft behaald in het seizoen 2009/2010.

# %% [markdown]
# [Terug naar het begin](#begin)

# %% [markdown]
# ## Sprint 5

# %%
display(match)

# %%
match['home_points'] = [3 if h > a else 1 if h == a else 0 for h, a in zip(match['home_team_goal'], match['away_team_goal'])]
match['away_points'] = [3 if a > h else 1 if a == h else 0 for h, a in zip(match['home_team_goal'], match['away_team_goal'])]
match['result'] = ['win' if row == 3 else 'draw' if row == 1 else 'defeat' for row in match['home_points']]
match
#win en defeat is gezien vanuit het home team
# Out:
#           id  country_id  league_id     season  stage                 date  \
# 0          1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1          2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2          3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3          4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4          5           1          1  2008/2009      1  2008-08-16 00:00:00
# ...      ...         ...        ...        ...    ...                  ...
# 25974  25975       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25975  25976       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25976  25977       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25977  25978       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25978  25979       24558      24558  2015/2016      9  2015-09-23 00:00:00
#
#        match_api_id  home_team_api_id  away_team_api_id  home_team_goal  \
# 0            492473              9987              9993               1
# 1            492474             10000              9994               0
# 2            492475              9984              8635               0
# 3            492476              9991              9998               5
# 4            492477              7947              9985               1
# ...             ...               ...               ...             ...
# 25974       1992091             10190             10191               1
# 25975       1992092              9824             10199               1
# 25976       1992093              9956             10179               2
# 25977       1992094              7896             10243               0
# 25978       1992095             10192              9931               4
#
#        away_team_goal  home_player_X1  home_player_X2  home_player_X3  \
# 0                   1             NaN             NaN             NaN
# 1                   0             NaN             NaN             NaN
# 2                   3             NaN             NaN             NaN
# 3                   0             NaN             NaN             NaN
# 4                   3             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 25974               0             1.0             2.0             4.0
# 25975               2             1.0             3.0             5.0
# 25976               0             1.0             2.0             4.0
# 25977               0             1.0             2.0             4.0
# 25978               3             1.0             2.0             4.0
#
#        home_player_X4  home_player_X5  home_player_X6  home_player_X7  \
# 0                 NaN             NaN             NaN             NaN
# 1                 NaN             NaN             NaN             NaN
# 2                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 4                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 25974             6.0             8.0             4.0             6.0
# 25975             7.0             2.0             4.0             6.0
# 25976             6.0             8.0             4.0             6.0
# 25977             6.0             8.0             3.0             7.0
# 25978             6.0             8.0             2.0             4.0
#
#        home_player_X8  home_player_X9  home_player_X10  home_player_X11  \
# 0                 NaN             NaN              NaN              NaN
# 1                 NaN             NaN              NaN              NaN
# 2                 NaN             NaN              NaN              NaN
# 3                 NaN             NaN              NaN              NaN
# 4                 NaN             NaN              NaN              NaN
# ...               ...             ...              ...              ...
# 25974             3.0             5.0              7.0              5.0
# 25975             8.0             5.0              4.0              6.0
# 25976             3.0             5.0              7.0              5.0
# 25977             5.0             3.0              5.0              7.0
# 25978             6.0             8.0              4.0              6.0
#
#        away_player_X1  away_player_X2  away_player_X3  away_player_X4  \
# 0                 NaN             NaN             NaN             NaN
# 1                 NaN             NaN             NaN             NaN
# 2                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 4                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 25974             1.0             2.0             4.0             6.0
# 25975             1.0             2.0             4.0             6.0
# 25976             1.0             2.0             4.0             6.0
# 25977             1.0             2.0             4.0             6.0
# 25978             1.0             2.0             4.0             6.0
#
#        away_player_X5  away_player_X6  away_player_X7  away_player_X8  \
# 0                 NaN             NaN             NaN             NaN
# 1                 NaN             NaN             NaN             NaN
# 2                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 4                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 25974             8.0             4.0             6.0             3.0
# 25975             8.0             3.0             5.0             7.0
# 25976             8.0             4.0             6.0             3.0
# 25977             8.0             4.0             6.0             3.0
# 25978             8.0             4.0             6.0             3.0
#
#        away_player_X9  away_player_X10  away_player_X11  home_player_Y1  \
# 0                 NaN              NaN              NaN             NaN
# 1                 NaN              NaN              NaN             NaN
# 2                 NaN              NaN              NaN             NaN
# 3                 NaN              NaN              NaN             NaN
# 4                 NaN              NaN              NaN             NaN
# ...               ...              ...              ...             ...
# 25974             5.0              7.0              5.0             1.0
# 25975             3.0              5.0              7.0             1.0
# 25976             5.0              7.0              5.0             1.0
# 25977             5.0              7.0              5.0             1.0
# 25978             5.0              7.0              5.0             1.0
#
#        home_player_Y2  home_player_Y3  home_player_Y4  home_player_Y5  \
# 0                 NaN             NaN             NaN             NaN
# 1                 NaN             NaN             NaN             NaN
# 2                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 4                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 25974             3.0             3.0             3.0             3.0
# 25975             3.0             3.0             3.0             7.0
# 25976             3.0             3.0             3.0             3.0
# 25977             3.0             3.0             3.0             3.0
# 25978             3.0             3.0             3.0             3.0
#
#        home_player_Y6  home_player_Y7  home_player_Y8  home_player_Y9  \
# 0                 NaN             NaN             NaN             NaN
# 1                 NaN             NaN             NaN             NaN
# 2                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 4                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 25974             6.0             6.0             8.0             8.0
# 25975             7.0             7.0             7.0             9.0
# 25976             6.0             6.0             8.0             8.0
# 25977             7.0             7.0             7.0            10.0
# 25978             7.0             7.0             7.0             7.0
#
#        home_player_Y10  home_player_Y11  away_player_Y1  away_player_Y2  \
# 0                  NaN              NaN             NaN             NaN
# 1                  NaN              NaN             NaN             NaN
# 2                  NaN              NaN             NaN             NaN
# 3                  NaN              NaN             NaN             NaN
# 4                  NaN              NaN             NaN             NaN
# ...                ...              ...             ...             ...
# 25974              8.0             11.0             1.0             3.0
# 25975             11.0             11.0             1.0             3.0
# 25976              8.0             11.0             1.0             3.0
# 25977             10.0             10.0             1.0             3.0
# 25978             10.0             10.0             1.0             3.0
#
#        away_player_Y3  away_player_Y4  away_player_Y5  away_player_Y6  \
# 0                 NaN             NaN             NaN             NaN
# 1                 NaN             NaN             NaN             NaN
# 2                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 4                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 25974             3.0             3.0             3.0             6.0
# 25975             3.0             3.0             3.0             7.0
# 25976             3.0             3.0             3.0             6.0
# 25977             3.0             3.0             3.0             6.0
# 25978             3.0             3.0             3.0             6.0
#
#        away_player_Y7  away_player_Y8  away_player_Y9  away_player_Y10  \
# 0                 NaN             NaN             NaN              NaN
# 1                 NaN             NaN             NaN              NaN
# 2                 NaN             NaN             NaN              NaN
# 3                 NaN             NaN             NaN              NaN
# 4                 NaN             NaN             NaN              NaN
# ...               ...             ...             ...              ...
# 25974             6.0             8.0             8.0              8.0
# 25975             7.0             7.0            10.0             10.0
# 25976             6.0             8.0             8.0              8.0
# 25977             6.0             8.0             8.0              8.0
# 25978             6.0             8.0             8.0              8.0
#
#        away_player_Y11  home_player_1  home_player_2  home_player_3  \
# 0                  NaN            NaN            NaN            NaN
# 1                  NaN            NaN            NaN            NaN
# 2                  NaN            NaN            NaN            NaN
# 3                  NaN            NaN            NaN            NaN
# 4                  NaN            NaN            NaN            NaN
# ...                ...            ...            ...            ...
# 25974             11.0        42231.0       678384.0        95220.0
# 25975             10.0        33272.0        41621.0        25813.0
# 25976             11.0       157856.0       274779.0       177689.0
# 25977             11.0            NaN         8881.0       173534.0
# 25978             11.0       274787.0       492132.0       108451.0
#
#        home_player_4  home_player_5  home_player_6  home_player_7  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 25974       638592.0       413155.0        45780.0       171229.0
# 25975       257845.0       114735.0        42237.0       113227.0
# 25976       294256.0        42258.0        39979.0       173936.0
# 25977        39646.0       282287.0       340790.0       393337.0
# 25978        25815.0        94553.0       384376.0       598355.0
#
#        home_player_8  home_player_9  home_player_10  home_player_11  \
# 0                NaN            NaN             NaN             NaN
# 1                NaN            NaN             NaN             NaN
# 2                NaN            NaN             NaN             NaN
# 3                NaN            NaN             NaN             NaN
# 4                NaN            NaN             NaN             NaN
# ...              ...            ...             ...             ...
# 25974        67333.0       119839.0        143790.0        195215.0
# 25975       358156.0        32343.0        531309.0         37257.0
# 25976       147959.0       451983.0         80564.0        289472.0
# 25977         8893.0       614454.0         93229.0        178142.0
# 25978        36785.0        45174.0        302079.0         71764.0
#
#        away_player_1  away_player_2  away_player_3  away_player_4  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 25974       462944.0       563066.0         8800.0        67304.0
# 25975        42276.0       114792.0       150007.0       178119.0
# 25976        10637.0        67349.0       202663.0        32597.0
# 25977       274776.0       121080.0       197757.0       260964.0
# 25978       156175.0        95216.0       172768.0        22834.0
#
#        away_player_5  away_player_6  away_player_7  away_player_8  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 25974       158253.0       133126.0       186524.0        93223.0
# 25975        27232.0       570830.0       260708.0       201704.0
# 25976       114794.0       188114.0        25840.0       482200.0
# 25977       231614.0       113235.0        41116.0       462608.0
# 25978       458806.0       207234.0        25772.0        40274.0
#
#        away_player_9  away_player_10  away_player_11  goal shoton shotoff  \
# 0                NaN             NaN             NaN  None   None    None
# 1                NaN             NaN             NaN  None   None    None
# 2                NaN             NaN             NaN  None   None    None
# 3                NaN             NaN             NaN  None   None    None
# 4                NaN             NaN             NaN  None   None    None
# ...              ...             ...             ...   ...    ...     ...
# 25974       121115.0        232110.0        289732.0  None   None    None
# 25975        36382.0         34082.0         95257.0  None   None    None
# 25976        95230.0        451335.0        275122.0  None   None    None
# 25977        42262.0         92252.0        194532.0  None   None    None
# 25978        34035.0         41726.0        527103.0  None   None    None
#
#       foulcommit  card cross corner possession  B365H  B365D  B365A   BWH  \
# 0           None  None  None   None       None   1.73   3.40   5.00  1.75
# 1           None  None  None   None       None   1.95   3.20   3.60  1.80
# 2           None  None  None   None       None   2.38   3.30   2.75  2.40
# 3           None  None  None   None       None   1.44   3.75   7.50  1.40
# 4           None  None  None   None       None   5.00   3.50   1.65  5.00
# ...          ...   ...   ...    ...        ...    ...    ...    ...   ...
# 25974       None  None  None   None       None    NaN    NaN    NaN   NaN
# 25975       None  None  None   None       None    NaN    NaN    NaN   NaN
# 25976       None  None  None   None       None    NaN    NaN    NaN   NaN
# 25977       None  None  None   None       None    NaN    NaN    NaN   NaN
# 25978       None  None  None   None       None    NaN    NaN    NaN   NaN
#
#         BWD   BWA   IWH  IWD  IWA   LBH  LBD   LBA  PSH  PSD  PSA   WHH   WHD  \
# 0      3.35  4.20  1.85  3.2  3.5  1.80  3.3  3.75  NaN  NaN  NaN  1.70  3.30
# 1      3.30  3.95  1.90  3.2  3.5  1.90  3.2  3.50  NaN  NaN  NaN  1.83  3.30
# 2      3.30  2.55  2.60  3.1  2.3  2.50  3.2  2.50  NaN  NaN  NaN  2.50  3.25
# 3      4.00  6.80  1.40  3.9  6.0  1.44  3.6  6.50  NaN  NaN  NaN  1.44  3.75
# 4      3.50  1.60  4.00  3.3  1.7  4.00  3.4  1.72  NaN  NaN  NaN  4.20  3.40
# ...     ...   ...   ...  ...  ...   ...  ...   ...  ...  ...  ...   ...   ...
# 25974   NaN   NaN   NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN  NaN   NaN   NaN
# 25975   NaN   NaN   NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN  NaN   NaN   NaN
# 25976   NaN   NaN   NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN  NaN   NaN   NaN
# 25977   NaN   NaN   NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN  NaN   NaN   NaN
# 25978   NaN   NaN   NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN  NaN   NaN   NaN
#
#         WHA   SJH  SJD   SJA   VCH   VCD   VCA   GBH   GBD   GBA   BSH   BSD  \
# 0      4.33  1.90  3.3  4.00  1.65  3.40  4.50  1.78  3.25  4.00  1.73  3.40
# 1      3.60  1.95  3.3  3.80  2.00  3.25  3.25  1.85  3.25  3.75  1.91  3.25
# 2      2.40  2.63  3.3  2.50  2.35  3.25  2.65  2.50  3.20  2.50  2.30  3.20
# 3      6.00  1.44  4.0  7.50  1.45  3.75  6.50  1.50  3.75  5.50  1.44  3.75
# 4      1.70  4.50  3.5  1.73  4.50  3.40  1.65  4.50  3.50  1.65  4.75  3.30
# ...     ...   ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 25974   NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25975   NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25976   NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25977   NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25978   NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#         BSA  home_points  away_points  result
# 0      4.20            1            1    draw
# 1      3.60            1            1    draw
# 2      2.75            0            3  defeat
# 3      6.50            3            0     win
# 4      1.67            0            3  defeat
# ...     ...          ...          ...     ...
# 25974   NaN            3            0     win
# 25975   NaN            0            3  defeat
# 25976   NaN            3            0     win
# 25977   NaN            1            1    draw
# 25978   NaN            3            0     win
#
# [25979 rows x 118 columns]

# %%
reactions en overall rating

# %%
team_attributes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458 entries, 0 to 1457
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              1458 non-null   int64
#  1   team_fifa_api_id                1458 non-null   int64
#  2   team_api_id                     1458 non-null   int64
#  3   date                            1458 non-null   object
#  4   buildUpPlaySpeed                1458 non-null   int64
#  5   buildUpPlaySpeedClass           1458 non-null   object
#  6   buildUpPlayDribbling            489 non-null    float64
#  7   buildUpPlayDribblingClass       1458 non-null   object
#  8   buildUpPlayPassing              1458 non-null   int64
#  9   buildUpPlayPassingClass         1458 non-null   object
#  10  buildUpPlayPositioningClass     1458 non-null   object
#  11  chanceCreationPassing           1458 non-null   int64
#  12  chanceCreationPassingClass      1458 non-null   object
#  13  chanceCreationCrossing          1458 non-null   int64
#  14  chanceCreationCrossingClass     1458 non-null   object
#  15  chanceCreationShooting          1458 non-null   int64
#  16  chanceCreationShootingClass     1458 non-null   object
#  17  chanceCreationPositioningClass  1458 non-null   object
#  18  defencePressure                 1458 non-null   int64
#  19  defencePressureClass            1458 non-null   object
#  20  defenceAggression               1458 non-null   int64
#  21  defenceAggressionClass          1458 non-null   object
#  22  defenceTeamWidth                1458 non-null   int64
#  23  defenceTeamWidthClass           1458 non-null   object
#  24  defenceDefenderLineClass        1458 non-null   object
#  25  season                          1458 non-null   object
# dtypes: float64(1), int64(11), object(14)
# memory usage: 296.3+ KB

# %%
hallo = team_attributes[['team_api_id','season','buildUpPlaySpeed', 'buildUpPlayDribbling', 'buildUpPlayPassing', 'chanceCreationPassing', 'chanceCreationCrossing', 'chanceCreationShooting', 'defencePressure', 'defenceAggression', 'defenceTeamWidth']]
hallo
# Out:
#       team_api_id     season  buildUpPlaySpeed  buildUpPlayDribbling  \
# 0            9930  2009/2010                60                   NaN
# 1            9930  2014/2015                52                  48.0
# 2            9930  2015/2016                47                  41.0
# 3            8485  2009/2010                70                   NaN
# 4            8485  2010/2011                47                   NaN
# ...           ...        ...               ...                   ...
# 1453        10000  2010/2011                52                   NaN
# 1454        10000  2011/2012                54                   NaN
# 1455        10000  2013/2014                54                   NaN
# 1456        10000  2014/2015                54                  42.0
# 1457        10000  2015/2016                54                  42.0
#
#       buildUpPlayPassing  chanceCreationPassing  chanceCreationCrossing  \
# 0                     50                     60                      65
# 1                     56                     54                      63
# 2                     54                     54                      63
# 3                     70                     70                      70
# 4                     52                     53                      48
# ...                  ...                    ...                     ...
# 1453                  52                     52                      48
# 1454                  51                     47                      52
# 1455                  51                     47                      52
# 1456                  51                     47                      52
# 1457                  51                     47                      52
#
#       chanceCreationShooting  defencePressure  defenceAggression  \
# 0                         55               50                 55
# 1                         64               47                 44
# 2                         64               47                 44
# 3                         70               60                 70
# 4                         52               47                 47
# ...                      ...              ...                ...
# 1453                      53               46                 48
# 1454                      50               44                 55
# 1455                      32               44                 58
# 1456                      32               44                 58
# 1457                      32               44                 58
#
#       defenceTeamWidth
# 0                   45
# 1                   54
# 2                   54
# 3                   70
# 4                   52
# ...                ...
# 1453                53
# 1454                53
# 1455                37
# 1456                37
# 1457                37
#
# [1458 rows x 11 columns]

# %%
hoi = match.copy()
hey = pd.merge(hoi,hallo,how='left', left_on =['home_team_api_id','season'], right_on = ['team_api_id', 'season'])
hey[hey['home_team_api_id'] == 9791]
# Out:
#           id  country_id  league_id     season  stage                 date  \
# 13278  13279       13274      13274  2008/2009      1  2008-08-31 00:00:00
# 13285  13286       13274      13274  2008/2009     10  2008-11-08 00:00:00
# 13312  13313       13274      13274  2008/2009     13  2008-11-29 00:00:00
# 13333  13334       13274      13274  2008/2009     15  2008-12-14 00:00:00
# 13347  13348       13274      13274  2008/2009     17  2008-12-27 00:00:00
# ...      ...         ...        ...        ...    ...                  ...
# 15655  15656       13274      13274  2015/2016     33  2016-05-01 00:00:00
# 15671  15672       13274      13274  2015/2016      4  2015-08-29 00:00:00
# 15688  15689       13274      13274  2015/2016      6  2015-09-19 00:00:00
# 15703  15704       13274      13274  2015/2016      8  2015-10-02 00:00:00
# 15714  15715       13274      13274  2015/2016      9  2015-10-17 00:00:00
#
#        match_api_id  home_team_api_id  away_team_api_id  home_team_goal  \
# 13278        508307              9791             10235               3
# 13285        523734              9791              8277               0
# 13312        523761              9791              8525               1
# 13333        523782              9791              8614               2
# 13347        523796              9791              8526               0
# ...             ...               ...               ...             ...
# 15655       1983566              9791             10217               1
# 15671       1983303              9791              8611               2
# 15688       1983320              9791              8640               2
# 15703       1983335              9791             10228               2
# 15714       1983346              9791              8593               0
#
#        away_team_goal  home_player_X1  home_player_X2  home_player_X3  \
# 13278               1             0.0             0.0             NaN
# 13285               0             NaN             NaN             NaN
# 13312               0             NaN             NaN             NaN
# 13333               1             NaN             NaN             NaN
# 13347               0             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 15655               1             1.0             2.0             4.0
# 15671               0             1.0             2.0             4.0
# 15688               1             1.0             2.0             4.0
# 15703               0             1.0             2.0             4.0
# 15714               2             1.0             2.0             4.0
#
#        home_player_X4  home_player_X5  home_player_X6  home_player_X7  \
# 13278             NaN             NaN             NaN             NaN
# 13285             NaN             NaN             NaN             NaN
# 13312             NaN             NaN             NaN             NaN
# 13333             NaN             NaN             NaN             NaN
# 13347             NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 15655             6.0             8.0             3.0             5.0
# 15671             6.0             8.0             3.0             5.0
# 15688             6.0             8.0             3.0             5.0
# 15703             6.0             8.0             3.0             5.0
# 15714             6.0             8.0             3.0             5.0
#
#        home_player_X8  home_player_X9  home_player_X10  home_player_X11  \
# 13278             NaN             NaN              NaN              NaN
# 13285             NaN             NaN              NaN              NaN
# 13312             NaN             NaN              NaN              NaN
# 13333             NaN             NaN              NaN              NaN
# 13347             NaN             NaN              NaN              NaN
# ...               ...             ...              ...              ...
# 15655             7.0             3.0              5.0              7.0
# 15671             7.0             3.0              5.0              7.0
# 15688             7.0             3.0              5.0              7.0
# 15703             7.0             3.0              5.0              7.0
# 15714             7.0             3.0              5.0              7.0
#
#        away_player_X1  away_player_X2  away_player_X3  away_player_X4  \
# 13278             NaN             NaN             NaN             NaN
# 13285             NaN             NaN             NaN             NaN
# 13312             NaN             NaN             NaN             NaN
# 13333             NaN             NaN             NaN             NaN
# 13347             NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 15655             1.0             2.0             4.0             6.0
# 15671             1.0             2.0             4.0             6.0
# 15688             1.0             2.0             4.0             6.0
# 15703             1.0             2.0             4.0             6.0
# 15714             1.0             2.0             4.0             6.0
#
#        away_player_X5  away_player_X6  away_player_X7  away_player_X8  \
# 13278             NaN             NaN             NaN             NaN
# 13285             NaN             NaN             NaN             NaN
# 13312             NaN             NaN             NaN             NaN
# 13333             NaN             NaN             NaN             NaN
# 13347             NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 15655             8.0             3.0             5.0             7.0
# 15671             8.0             3.0             5.0             7.0
# 15688             8.0             3.0             5.0             7.0
# 15703             8.0             3.0             5.0             7.0
# 15714             8.0             3.0             5.0             7.0
#
#        away_player_X9  away_player_X10  away_player_X11  home_player_Y1  \
# 13278             NaN              NaN              NaN             0.0
# 13285             NaN              NaN              NaN             NaN
# 13312             NaN              NaN              NaN             NaN
# 13333             NaN              NaN              NaN             NaN
# 13347             NaN              NaN              NaN             NaN
# ...               ...              ...              ...             ...
# 15655             3.0              5.0              7.0             1.0
# 15671             3.0              5.0              7.0             1.0
# 15688             3.0              5.0              7.0             1.0
# 15703             3.0              5.0              7.0             1.0
# 15714             3.0              5.0              7.0             1.0
#
#        home_player_Y2  home_player_Y3  home_player_Y4  home_player_Y5  \
# 13278             0.0             NaN             NaN             NaN
# 13285             NaN             NaN             NaN             NaN
# 13312             NaN             NaN             NaN             NaN
# 13333             NaN             NaN             NaN             NaN
# 13347             NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 15655             3.0             3.0             3.0             3.0
# 15671             3.0             3.0             3.0             3.0
# 15688             3.0             3.0             3.0             3.0
# 15703             3.0             3.0             3.0             3.0
# 15714             3.0             3.0             3.0             3.0
#
#        home_player_Y6  home_player_Y7  home_player_Y8  home_player_Y9  \
# 13278             NaN             NaN             NaN             NaN
# 13285             NaN             NaN             NaN             NaN
# 13312             NaN             NaN             NaN             NaN
# 13333             NaN             NaN             NaN             NaN
# 13347             NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 15655             7.0             7.0             7.0            10.0
# 15671             7.0             7.0             7.0            10.0
# 15688             7.0             7.0             7.0            10.0
# 15703             7.0             7.0             7.0            10.0
# 15714             7.0             7.0             7.0            10.0
#
#        home_player_Y10  home_player_Y11  away_player_Y1  away_player_Y2  \
# 13278              NaN              NaN             NaN             NaN
# 13285              NaN              NaN             NaN             NaN
# 13312              NaN              NaN             NaN             NaN
# 13333              NaN              NaN             NaN             NaN
# 13347              NaN              NaN             NaN             NaN
# ...                ...              ...             ...             ...
# 15655             10.0             10.0             1.0             3.0
# 15671             10.0             10.0             1.0             3.0
# 15688             10.0             10.0             1.0             3.0
# 15703             10.0             10.0             1.0             3.0
# 15714             10.0             10.0             1.0             3.0
#
#        away_player_Y3  away_player_Y4  away_player_Y5  away_player_Y6  \
# 13278             NaN             NaN             NaN             NaN
# 13285             NaN             NaN             NaN             NaN
# 13312             NaN             NaN             NaN             NaN
# 13333             NaN             NaN             NaN             NaN
# 13347             NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 15655             3.0             3.0             3.0             7.0
# 15671             3.0             3.0             3.0             7.0
# 15688             3.0             3.0             3.0             7.0
# 15703             3.0             3.0             3.0             7.0
# 15714             3.0             3.0             3.0             7.0
#
#        away_player_Y7  away_player_Y8  away_player_Y9  away_player_Y10  \
# 13278             NaN             NaN             NaN              NaN
# 13285             NaN             NaN             NaN              NaN
# 13312             NaN             NaN             NaN              NaN
# 13333             NaN             NaN             NaN              NaN
# 13347             NaN             NaN             NaN              NaN
# ...               ...             ...             ...              ...
# 15655             7.0             7.0            10.0             10.0
# 15671             7.0             7.0            10.0             10.0
# 15688             7.0             7.0            10.0             10.0
# 15703             7.0             7.0            10.0             10.0
# 15714             7.0             7.0            10.0             10.0
#
#        away_player_Y11  home_player_1  home_player_2  home_player_3  \
# 13278              NaN        26663.0       110116.0        26671.0
# 13285              NaN            NaN            NaN            NaN
# 13312              NaN            NaN            NaN            NaN
# 13333              NaN            NaN            NaN            NaN
# 13347              NaN            NaN            NaN            NaN
# ...                ...            ...            ...            ...
# 15655             10.0        26589.0       518346.0        31296.0
# 15671             10.0        26589.0       147601.0       213167.0
# 15688             10.0        26589.0       147601.0       213167.0
# 15703             10.0        26589.0       147601.0       213167.0
# 15714             10.0        26589.0       147601.0       213167.0
#
#        home_player_4  home_player_5  home_player_6  home_player_7  \
# 13278        37965.0        26661.0        26664.0        26648.0
# 13285            NaN            NaN            NaN            NaN
# 13312            NaN            NaN            NaN            NaN
# 13333            NaN            NaN            NaN            NaN
# 13347            NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 15655       518535.0        26455.0       243439.0       248151.0
# 15671        31296.0        26455.0       248151.0       243439.0
# 15688        31296.0        26455.0       243439.0       248151.0
# 15703        31296.0       518346.0       243439.0       248151.0
# 15714        31296.0        26455.0       243439.0       248151.0
#
#        home_player_8  home_player_9  home_player_10  home_player_11  \
# 13278        26660.0        26492.0        104045.0             NaN
# 13285            NaN            NaN             NaN             NaN
# 13312            NaN            NaN             NaN             NaN
# 13333            NaN            NaN             NaN             NaN
# 13347            NaN            NaN             NaN             NaN
# ...              ...            ...             ...             ...
# 15655       213682.0       422128.0        351999.0        243473.0
# 15671       213682.0       360560.0        351999.0        281110.0
# 15688       213682.0       360560.0        351999.0        281110.0
# 15703       213682.0       243473.0        351999.0        422128.0
# 15714       213682.0       422128.0        351999.0        518346.0
#
#        away_player_1  away_player_2  away_player_3  away_player_4  \
# 13278        34489.0        26445.0        34492.0        41462.0
# 13285            NaN            NaN            NaN            NaN
# 13312            NaN            NaN            NaN            NaN
# 13333            NaN            NaN            NaN            NaN
# 13347            NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 15655        47532.0       561844.0       212370.0       350986.0
# 15671       209785.0       574234.0       228982.0       187336.0
# 15688       150236.0       207642.0       184821.0        70812.0
# 15703       112107.0       243465.0       611831.0       363369.0
# 15714         5710.0       469804.0       304455.0       496563.0
#
#        away_player_5  away_player_6  away_player_7  away_player_8  \
# 13278        30916.0        24123.0       109638.0       108038.0
# 13285            NaN            NaN            NaN            NaN
# 13312            NaN            NaN            NaN            NaN
# 13333            NaN            NaN            NaN            NaN
# 13347            NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 15655       101042.0       417818.0        26813.0       279107.0
# 15671       619297.0       186847.0       360559.0       188533.0
# 15688       389845.0       178765.0       467495.0       209372.0
# 15703       215369.0       214397.0       110214.0       255221.0
# 15714       352366.0       467479.0       298448.0       178753.0
#
#        away_player_9  away_player_10  away_player_11  \
# 13278        30654.0         37173.0             NaN
# 13285            NaN             NaN             NaN
# 13312            NaN             NaN             NaN
# 13333            NaN             NaN             NaN
# 13347            NaN             NaN             NaN
# ...              ...             ...             ...
# 15655        17855.0         20645.0        725718.0
# 15671       210956.0        371538.0         36133.0
# 15688       158581.0        150201.0        166575.0
# 15703       303926.0             NaN        318809.0
# 15714        39213.0        562267.0        266526.0
#
#                                                     goal  \
# 13278                                               None
# 13285                                               None
# 13312                                               None
# 13333                                               None
# 13347                                               None
# ...                                                  ...
# 15655  <goal><value><comment>n</comment><stats><goals...
# 15671  <goal><value><comment>n</comment><stats><goals...
# 15688  <goal><value><comment>n</comment><stats><goals...
# 15703  <goal><value><comment>n</comment><stats><goals...
# 15714  <goal><value><comment>n</comment><stats><goals...
#
#                                                   shoton  \
# 13278                                               None
# 13285                                               None
# 13312                                               None
# 13333                                               None
# 13347                                               None
# ...                                                  ...
# 15655  <shoton><value><stats><shoton>1</shoton></stat...
# 15671  <shoton><value><stats><shoton>1</shoton></stat...
# 15688  <shoton><value><stats><shoton>1</shoton></stat...
# 15703  <shoton><value><stats><blocked>1</blocked></st...
# 15714  <shoton><value><stats><shoton>1</shoton></stat...
#
#                                                  shotoff  \
# 13278                                               None
# 13285                                               None
# 13312                                               None
# 13333                                               None
# 13347                                               None
# ...                                                  ...
# 15655  <shotoff><value><stats><shotoff>1</shotoff></s...
# 15671  <shotoff><value><stats><shotoff>1</shotoff></s...
# 15688  <shotoff><value><stats><shotoff>1</shotoff></s...
# 15703  <shotoff><value><event_incident_typefk>743</ev...
# 15714  <shotoff><value><stats><shotoff>1</shotoff></s...
#
#                                               foulcommit  \
# 13278                                               None
# 13285                                               None
# 13312                                               None
# 13333                                               None
# 13347                                               None
# ...                                                  ...
# 15655  <foulcommit><value><stats><foulscommitted>1</f...
# 15671  <foulcommit><value><stats><foulscommitted>1</f...
# 15688  <foulcommit><value><stats><foulscommitted>1</f...
# 15703  <foulcommit><value><stats><foulscommitted>1</f...
# 15714  <foulcommit><value><stats><foulscommitted>1</f...
#
#                                                     card  \
# 13278                                               None
# 13285                                               None
# 13312                                               None
# 13333                                               None
# 13347                                               None
# ...                                                  ...
# 15655  <card><value><comment>y</comment><stats><ycard...
# 15671  <card><value><comment>y</comment><stats><ycard...
# 15688  <card><value><comment>y</comment><stats><ycard...
# 15703  <card><value><comment>y</comment><stats><ycard...
# 15714  <card><value><comment>y</comment><stats><ycard...
#
#                                                    cross  \
# 13278                                               None
# 13285                                               None
# 13312                                               None
# 13333                                               None
# 13347                                               None
# ...                                                  ...
# 15655  <cross><value><stats><crosses>1</crosses></sta...
# 15671  <cross><value><stats><crosses>1</crosses></sta...
# 15688  <cross><value><stats><crosses>1</crosses></sta...
# 15703  <cross><value><stats><crosses>1</crosses></sta...
# 15714  <cross><value><stats><crosses>1</crosses></sta...
#
#                                                   corner  \
# 13278                                               None
# 13285                                               None
# 13312                                               None
# 13333                                               None
# 13347                                               None
# ...                                                  ...
# 15655  <corner><value><stats><corners>1</corners></st...
# 15671  <corner><value><stats><corners>1</corners></st...
# 15688  <corner><value><stats><corners>1</corners></st...
# 15703  <corner><value><stats><corners>1</corners></st...
# 15714  <corner><value><stats><corners>1</corners></st...
#
#                                               possession  B365H  B365D  B365A  \
# 13278                                               None   4.33   3.25   1.80
# 13285                                               None   2.20   3.40   3.20
# 13312                                               None   2.30   3.25   2.80
# 13333                                               None   1.91   3.30   3.75
# 13347                                               None   1.66   3.40   4.50
# ...                                                  ...    ...    ...    ...
# 15655  <possession><value><comment>50</comment><stats...   1.95   3.60   3.60
# 15671  <possession><value><comment>51</comment><stats...   2.40   3.50   2.75
# 15688  <possession><value><comment>63</comment><stats...   4.33   4.33   1.67
# 15703  <possession><value><comment>53</comment><stats...   2.05   3.60   3.30
# 15714  <possession><value><comment>48</comment><stats...   4.00   3.75   1.83
#
#         BWH   BWD   BWA   IWH  IWD   IWA   LBH   LBD  LBA   PSH   PSD   PSA  \
# 13278  3.80  3.40  1.80  3.90  3.3  1.75  3.75  3.30  1.8   NaN   NaN   NaN
# 13285  2.00  3.30  3.35  2.20  3.2  2.75  2.00  3.20  3.2   NaN   NaN   NaN
# 13312  2.30  3.35  2.70  2.30  3.2  2.50  2.25  3.40  2.6   NaN   NaN   NaN
# 13333  1.95  3.25  3.55  1.90  3.3  3.30  1.91  3.25  3.4   NaN   NaN   NaN
# 13347  1.70  3.40  4.50  1.75  3.3  3.80  1.67  3.30  4.5   NaN   NaN   NaN
# ...     ...   ...   ...   ...  ...   ...   ...   ...  ...   ...   ...   ...
# 15655  1.87  3.60  3.70  1.85  3.5  3.70  1.95  3.60  3.6  2.02  3.76  3.80
# 15671  2.45  3.40  2.65  2.50  3.3  2.50  2.50  3.50  2.7  2.55  3.65  2.74
# 15688  4.75  3.90  1.62  4.80  3.6  1.60  4.33  4.00  1.7  4.69  4.18  1.75
# 15703  2.05  3.60  3.20  2.00  3.4  3.20  2.00  3.60  3.4  2.07  3.80  3.58
# 15714  3.90  3.50  1.85  3.80  3.5  1.80  4.00  3.80  1.8  4.17  3.87  1.90
#
#         WHH   WHD   WHA   SJH   SJD   SJA   VCH   VCD   VCA   GBH   GBD   GBA  \
# 13278  4.20  3.40  1.70  4.75  3.50  1.73  4.35  3.40  1.70  4.00  3.40  1.80
# 13285  2.05  3.40  2.90  2.10  3.40  3.25  2.25  3.30  2.75  2.10  3.25  3.25
# 13312  2.15  3.30  2.80  2.50  3.25  2.63  2.25  3.40  2.65  2.35  3.30  2.80
# 13333  1.83  3.40  3.50  1.91  3.40  3.50  1.85  3.40  3.60  1.95  3.30  3.60
# 13347  1.62  3.75  4.20  1.73  3.40  4.33  1.70  3.40  4.35  1.70  3.50  4.75
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 15655  2.00  3.50  3.30   NaN   NaN   NaN  2.00  3.75  3.50   NaN   NaN   NaN
# 15671  2.30  3.50  2.70   NaN   NaN   NaN  2.40  3.75  2.70   NaN   NaN   NaN
# 15688  4.00  4.20  1.67   NaN   NaN   NaN  4.60  4.33  1.70   NaN   NaN   NaN
# 15703  2.00  3.75  3.00   NaN   NaN   NaN  2.05  3.80  3.50   NaN   NaN   NaN
# 15714  3.75  3.60  1.83   NaN   NaN   NaN  4.10  3.90  1.83   NaN   NaN   NaN
#
#         BSH  BSD   BSA  home_points  away_points  result  team_api_id  \
# 13278  4.33  3.3  1.73            3            0     win          NaN
# 13285  2.20  3.3  2.88            1            1    draw          NaN
# 13312  2.30  3.3  2.75            3            0     win          NaN
# 13333  1.91  3.3  3.50            3            0     win          NaN
# 13347  1.70  3.4  4.50            1            1    draw          NaN
# ...     ...  ...   ...          ...          ...     ...          ...
# 15655   NaN  NaN   NaN            1            1    draw       9791.0
# 15671   NaN  NaN   NaN            3            0     win       9791.0
# 15688   NaN  NaN   NaN            3            0     win       9791.0
# 15703   NaN  NaN   NaN            3            0     win       9791.0
# 15714   NaN  NaN   NaN            0            3  defeat       9791.0
#
#        buildUpPlaySpeed  buildUpPlayDribbling  buildUpPlayPassing  \
# 13278               NaN                   NaN                 NaN
# 13285               NaN                   NaN                 NaN
# 13312               NaN                   NaN                 NaN
# 13333               NaN                   NaN                 NaN
# 13347               NaN                   NaN                 NaN
# ...                 ...                   ...                 ...
# 15655              50.0                  36.0                61.0
# 15671              50.0                  36.0                61.0
# 15688              50.0                  36.0                61.0
# 15703              50.0                  36.0                61.0
# 15714              50.0                  36.0                61.0
#
#        chanceCreationPassing  chanceCreationCrossing  chanceCreationShooting  \
# 13278                    NaN                     NaN                     NaN
# 13285                    NaN                     NaN                     NaN
# 13312                    NaN                     NaN                     NaN
# 13333                    NaN                     NaN                     NaN
# 13347                    NaN                     NaN                     NaN
# ...                      ...                     ...                     ...
# 15655                   48.0                    58.0                    59.0
# 15671                   48.0                    58.0                    59.0
# 15688                   48.0                    58.0                    59.0
# 15703                   48.0                    58.0                    59.0
# 15714                   48.0                    58.0                    59.0
#
#        defencePressure  defenceAggression  defenceTeamWidth
# 13278              NaN                NaN               NaN
# 13285              NaN                NaN               NaN
# 13312              NaN                NaN               NaN
# 13333              NaN                NaN               NaN
# 13347              NaN                NaN               NaN
# ...                ...                ...               ...
# 15655             60.0               62.0              47.0
# 15671             60.0               62.0              47.0
# 15688             60.0               62.0              47.0
# 15703             60.0               62.0              47.0
# 15714             60.0               62.0              47.0
#
# [136 rows x 128 columns]
